# %% [markdown]
# # Studying a model performance with synthetic data
#
# Synthetic data have been created for each class, using as input the pictures that all models misclassify. The idea is the following: Maybe having more pics similar to the misclassified ones we can improve the performance of the model in that areas.
#
# - There are a test set with 150 real pics of each class.
# - Now, for each class, there are other 3 train/validation folders:
#   - With all real pics and 50 synthetic pics
#   - With all real pics and 250 synthetic pics
#   - With all real pics and 480 synthetic pics
#
#
# - The study of what pics were generated synthetically can be found here => https://github.com/albertovpd/viu_tfm-deep_vision_classification/tree/synthetic_data_study
#
# - They were created using the pytorch implementation of this repo => https://github.com/mit-han-lab/data-efficient-gans

# %%
# Google Drive stuff
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed May 25 15:27:43 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    46W / 350W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# tf
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# - libs

# %%
# %tensorflow_version 2.x
# batch ingestion of pics without pickle
from tensorflow.keras.preprocessing import image_dataset_from_directory

# nns
from tensorflow.keras.applications import ResNet50 

from tensorflow.keras import Model
from tensorflow.keras.models import load_model # Sequential
from tensorflow.keras import layers 

# optimization
from tensorflow.keras.optimizers import SGD #Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy, categorical_crossentropy
from tensorflow.keras.callbacks import EarlyStopping

# nn architectures, metrics, viz & reports => written in my_functions202202 file
import sys
sys.path.append("/content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/src")
from my_functions202202 import generic_last_2layers, plotting_model, model_evaluation, classification_report_pic, confusion_matrix_report

import numpy as np
# %matplotlib inline

# navigating through folder
import os

# %% [markdown]
# - paths

# %%
base_folder = "/content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/"
trainval_folders = base_folder + "input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/"
test_folder = base_folder+"input/dataset_synth_data-1test_3trainval_20220525/test_ds/"

src_folder =  base_folder+"src/"
output_folder = base_folder + "/output/"

# %% [markdown]
# - functions

# %%
#my_functions202202.py

# %% [markdown]
# - common parameters

# %%
# resolution changed to 224 for every pic
image_size = (224,224)
batch_size = 128
epochs = 250
opt = SGD(momentum=0.9)

# %%
image_size[1]
# Out:
# 224

# %%
base_model_resnet50 = ResNet50(include_top=False, weights='imagenet', input_shape=(image_size[0], image_size[1], 3), classes = 5) 
models_dict = {"resnet50_NOdataAug_dropoutFirst007": 
         generic_last_2layers(data_augmentation= None, nn=base_model_resnet50, neurons_final_layer=5, dropout_layers=True,  dropout_position="first",  dropout_percent = 0.07)
         }

# %%
test_ds = image_dataset_from_directory(
    test_folder,
      class_names=["Bedroom","Bathroom","Dinning","Livingroom","Kitchen"],
      seed=None,
      validation_split=None, 
      subset=None,
      image_size= image_size,
      batch_size= batch_size,
      color_mode='rgb',
      shuffle=False 
  )
# Out:
# Found 750 files belonging to 5 classes.

# %%
# remaining_folders_irr = os.listdir(irreg_input)[2:3]
folders = os.listdir(trainval_folders)
folders
# Out:
# ['synth250_train_val_ds',
#  'no_synth_train_val_ds',
#  'synth50_train_val_ds',
#  'synth480_train_val_ds']

# %%
folders=folders[1:2]
folders
# Out:
# ['no_synth_train_val_ds']

# %%
for f in folders:
    print("\n ================================",
          "\n FOLDER : ",f)
    print("train dataset")
    train_path = trainval_folders+f+"/"+'train_ds/'
    print(train_path)
    train_ds = image_dataset_from_directory(
        train_path,
        class_names=["Bedroom","Bathroom","Dinning","Livingroom","Kitchen"],
        seed=None,
        validation_split=None, 
        subset=None,
        image_size= image_size,
        batch_size= batch_size,
        color_mode='rgb',
        shuffle=False 
        )

    print("\n val dataset")
    val_path = trainval_folders+f+"/"+"val_ds"
    val_ds = image_dataset_from_directory(
      val_path,
      class_names=["Bedroom","Bathroom","Dinning","Livingroom","Kitchen"],
      seed=None,
      validation_split=None, 
      subset=None,
      image_size= image_size,
      batch_size= batch_size,
      color_mode='rgb',
      shuffle=False 
    )

    class_names = train_ds.class_names
    print(class_names)

    # checking numbers non sense now because all have same volume
    paths = ['train_ds/', 'val_ds/']
    for p in paths:
        for dir,subdir,files in os.walk(trainval_folders+f+"/"+p):
            print(dir,' => ', p, str(len(files)))

    # calling model
    model_name, nn = list(models_dict.items())[0]
    print("\n", model_name)
    nn.summary()

    nn.compile( optimizer = opt, #"adam", 
                  loss=SparseCategoricalCrossentropy(from_logits=True) ,#'categorical_crossentropy', 
                  metrics=['accuracy'] # "recall"
                  )

    # ====== USING VAL DATASET ======

    history = nn.fit(
          train_ds,
          validation_data=val_ds,
          epochs=epochs,
          #callbacks = callbacks # <=== REMOVE CALLBACK for full results
          )

    number_of_epochs_it_ran = len(history.history['loss']) 
    print("run epochs: ",number_of_epochs_it_ran)
    name = model_name+f
    #models_dict[m].save(output_folder+name+".h5")

    # saving model accuracy/loss graph
    plotting_model(history,number_of_epochs_it_ran, name, output_folder, "val") 

    # saving model metrics to json
    evaluation = nn.evaluate(test_ds, batch_size=batch_size, return_dict=True)
    model_evaluation(evaluation, output_folder, name+"_trainVal")

    # get inferences
    y_pred_val_float = nn.predict(val_ds)
    y_pred_val = np.argmax(y_pred_val_float, axis=1)

    # get real labels
    y_target = tf.concat([y for x, y in val_ds], axis=0) 

    # classification and confusion matrix reports
    classification_report_pic(y_pred_val, y_target,  class_names, output_folder, name+"_trainVal")
    confusion_matrix_report(y_pred_val, y_target, class_names, output_folder, name+"_trainVal")

    # ====== USING TEST DATASET ======

    # saving model metrics to json
    evaluation_test = nn.evaluate(test_ds, batch_size=batch_size, return_dict=True)
    model_evaluation(evaluation_test, output_folder, name+"_trainTest")

    # get inferences
    y_pred_test_float = nn.predict(test_ds)
    y_pred_test = np.argmax(y_pred_test_float, axis=1)

    # get real labels for val_ds
    y_target_test = tf.concat([y for x, y in test_ds], axis=0) 

    # classification and confusion matrix reports
    classification_report_pic(y_pred_test, y_target_test,  class_names, output_folder, name+"_trainTest")
    confusion_matrix_report(y_pred_test, y_target_test, class_names, output_folder, name+"_trainTest")
# Out:
#  ================================
#  FOLDER :  no_synth_train_val_ds
# train dataset
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/no_synth_train_val_ds/train_ds/
# Found 3598 files belonging to 5 classes.
#
#  val dataset
# Found 902 files belonging to 5 classes.
# ['Bedroom', 'Bathroom', 'Dinning', 'Livingroom', 'Kitchen']
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/no_synth_train_val_ds/train_ds/  =>  train_ds/ 0
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/no_synth_train_val_ds/train_ds/Bedroom  =>  train_ds/ 878
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/no_synth_train_val_ds/train_ds/Dinning  =>  train_ds/ 806
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/no_synth_train_val_ds/train_ds/Kitchen  =>  train_ds/ 652
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/no_synth_train_val_ds/train_ds/Livingroom  =>  train_ds/ 898
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/no_synth_train_val_ds/train_ds/Bathroom  =>  train_ds/ 364
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/no_synth_train_val_ds/val_ds/  =>  val_ds/ 0
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/no_synth_train_val_ds/val_ds/Dinning  =>  val_ds/ 202
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/no_synth_train_val_ds/val_ds/Bedroom  =>  val_ds/ 220
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/no_synth_train_val_ds/val_ds/Bathroom  =>  val_ds/ 92
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/no_synth_train_val_ds/val_ds/Kitchen  =>  val_ds/ 163
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-1test_3trainval_20220525/train_val_ds/no_synth_train_val_ds/val_ds/Livingroom  =>  val_ds/ 225
#
#  resnet50_NOdataAug_dropoutFirst007
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  dropout (Dropout)           (None, 7, 7, 2048)        0
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 5)                 10245
#
# =================================================================
# Total params: 23,597,957
# Trainable params: 10,245
# Non-trainable params: 23,587,712
# _________________________________________________________________
# Epoch 1/250
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 29/29 [==============================] - 11s 165ms/step - loss: 57.8468 - accuracy: 0.3830 - val_loss: 211.7262 - val_accuracy: 0.2494
# Epoch 2/250
# 29/29 [==============================] - 4s 127ms/step - loss: 281.7784 - accuracy: 0.0111 - val_loss: 131.1164 - val_accuracy: 0.1940
# Epoch 3/250
# 29/29 [==============================] - 4s 127ms/step - loss: 189.3452 - accuracy: 0.0397 - val_loss: 53.8470 - val_accuracy: 0.4213
# Epoch 4/250
# 29/29 [==============================] - 4s 126ms/step - loss: 170.4393 - accuracy: 0.0948 - val_loss: 54.0531 - val_accuracy: 0.5277
# Epoch 5/250
# 29/29 [==============================] - 4s 126ms/step - loss: 154.7910 - accuracy: 0.1929 - val_loss: 39.6346 - val_accuracy: 0.5543
# Epoch 6/250
# 29/29 [==============================] - 4s 124ms/step - loss: 117.4214 - accuracy: 0.2932 - val_loss: 31.3236 - val_accuracy: 0.6186
# Epoch 7/250
# 29/29 [==============================] - 4s 127ms/step - loss: 110.8034 - accuracy: 0.3063 - val_loss: 27.6835 - val_accuracy: 0.6563
# Epoch 8/250
# 29/29 [==============================] - 4s 126ms/step - loss: 98.5468 - accuracy: 0.3382 - val_loss: 21.3568 - val_accuracy: 0.7007
# Epoch 9/250
# 29/29 [==============================] - 4s 123ms/step - loss: 88.0315 - accuracy: 0.3716 - val_loss: 18.2754 - val_accuracy: 0.7251
# Epoch 10/250
# 29/29 [==============================] - 4s 127ms/step - loss: 78.0565 - accuracy: 0.4116 - val_loss: 17.1194 - val_accuracy: 0.7417
# Epoch 11/250
# 29/29 [==============================] - 4s 124ms/step - loss: 72.7955 - accuracy: 0.4366 - val_loss: 16.8207 - val_accuracy: 0.7461
# Epoch 12/250
# 29/29 [==============================] - 4s 123ms/step - loss: 65.0271 - accuracy: 0.4703 - val_loss: 16.4183 - val_accuracy: 0.7561
# Epoch 13/250
# 29/29 [==============================] - 4s 124ms/step - loss: 54.0170 - accuracy: 0.5200 - val_loss: 15.6561 - val_accuracy: 0.7616
# Epoch 14/250
# 29/29 [==============================] - 4s 123ms/step - loss: 50.1143 - accuracy: 0.5414 - val_loss: 15.3635 - val_accuracy: 0.7672
# Epoch 15/250
# 29/29 [==============================] - 4s 123ms/step - loss: 46.8328 - accuracy: 0.5525 - val_loss: 15.2774 - val_accuracy: 0.7683
# Epoch 16/250
# 29/29 [==============================] - 4s 125ms/step - loss: 44.9782 - accuracy: 0.5559 - val_loss: 15.2308 - val_accuracy: 0.7705
# Epoch 17/250
# 29/29 [==============================] - 4s 125ms/step - loss: 43.8952 - accuracy: 0.5636 - val_loss: 15.1340 - val_accuracy: 0.7716
# Epoch 18/250
# 29/29 [==============================] - 4s 126ms/step - loss: 43.0454 - accuracy: 0.5628 - val_loss: 15.0848 - val_accuracy: 0.7727
# Epoch 19/250
# 29/29 [==============================] - 4s 126ms/step - loss: 41.3351 - accuracy: 0.5698 - val_loss: 14.9642 - val_accuracy: 0.7716
# Epoch 20/250
# 29/29 [==============================] - 4s 126ms/step - loss: 39.8596 - accuracy: 0.5800 - val_loss: 14.6992 - val_accuracy: 0.7716
# Epoch 21/250
# 29/29 [==============================] - 4s 122ms/step - loss: 38.6753 - accuracy: 0.5806 - val_loss: 14.8660 - val_accuracy: 0.7672
# Epoch 22/250
# 29/29 [==============================] - 4s 122ms/step - loss: 39.2115 - accuracy: 0.5742 - val_loss: 14.9452 - val_accuracy: 0.7672
# Epoch 23/250
# 29/29 [==============================] - 4s 124ms/step - loss: 38.7436 - accuracy: 0.5781 - val_loss: 14.7013 - val_accuracy: 0.7683
# Epoch 24/250
# 29/29 [==============================] - 4s 126ms/step - loss: 38.7767 - accuracy: 0.5720 - val_loss: 14.9074 - val_accuracy: 0.7627
# Epoch 25/250
# 29/29 [==============================] - 4s 125ms/step - loss: 38.8994 - accuracy: 0.5731 - val_loss: 14.5611 - val_accuracy: 0.7650
# Epoch 26/250
# 29/29 [==============================] - 4s 123ms/step - loss: 37.5874 - accuracy: 0.5778 - val_loss: 14.6357 - val_accuracy: 0.7616
# Epoch 27/250
# 29/29 [==============================] - 4s 127ms/step - loss: 37.3859 - accuracy: 0.5809 - val_loss: 14.2087 - val_accuracy: 0.7672
# Epoch 28/250
# 29/29 [==============================] - 4s 126ms/step - loss: 36.1827 - accuracy: 0.5848 - val_loss: 14.2502 - val_accuracy: 0.7694
# Epoch 29/250
# 29/29 [==============================] - 4s 126ms/step - loss: 35.7429 - accuracy: 0.5914 - val_loss: 13.7338 - val_accuracy: 0.7738
# Epoch 30/250
# 29/29 [==============================] - 4s 126ms/step - loss: 33.7983 - accuracy: 0.5967 - val_loss: 13.3510 - val_accuracy: 0.7772
# Epoch 31/250
# 29/29 [==============================] - 4s 126ms/step - loss: 33.3061 - accuracy: 0.6098 - val_loss: 13.0386 - val_accuracy: 0.7794
# Epoch 32/250
# 29/29 [==============================] - 4s 124ms/step - loss: 31.5628 - accuracy: 0.6190 - val_loss: 12.7803 - val_accuracy: 0.7849
# Epoch 33/250
# 29/29 [==============================] - 4s 127ms/step - loss: 31.3567 - accuracy: 0.6215 - val_loss: 12.5555 - val_accuracy: 0.7871
# Epoch 34/250
# 29/29 [==============================] - 4s 127ms/step - loss: 31.4132 - accuracy: 0.6223 - val_loss: 12.5094 - val_accuracy: 0.7827
# Epoch 35/250
# 29/29 [==============================] - 4s 126ms/step - loss: 31.6552 - accuracy: 0.6192 - val_loss: 12.3687 - val_accuracy: 0.7860
# Epoch 36/250
# 29/29 [==============================] - 4s 124ms/step - loss: 30.3564 - accuracy: 0.6287 - val_loss: 12.3238 - val_accuracy: 0.7882
# Epoch 37/250
# 29/29 [==============================] - 4s 126ms/step - loss: 30.6540 - accuracy: 0.6273 - val_loss: 12.2940 - val_accuracy: 0.7894
# Epoch 38/250
# 29/29 [==============================] - 4s 126ms/step - loss: 30.3428 - accuracy: 0.6259 - val_loss: 12.1502 - val_accuracy: 0.7927
# Epoch 39/250
# 29/29 [==============================] - 4s 126ms/step - loss: 29.7813 - accuracy: 0.6306 - val_loss: 12.0301 - val_accuracy: 0.7927
# Epoch 40/250
# 29/29 [==============================] - 4s 123ms/step - loss: 29.4616 - accuracy: 0.6345 - val_loss: 11.7742 - val_accuracy: 0.7960
# Epoch 41/250
# 29/29 [==============================] - 4s 126ms/step - loss: 28.9116 - accuracy: 0.6451 - val_loss: 11.5473 - val_accuracy: 0.8004
# Epoch 42/250
# 29/29 [==============================] - 4s 122ms/step - loss: 27.4894 - accuracy: 0.6540 - val_loss: 11.5512 - val_accuracy: 0.7960
# Epoch 43/250
# 29/29 [==============================] - 4s 126ms/step - loss: 26.8832 - accuracy: 0.6576 - val_loss: 11.5956 - val_accuracy: 0.7938
# Epoch 44/250
# 29/29 [==============================] - 4s 124ms/step - loss: 26.8302 - accuracy: 0.6529 - val_loss: 11.4349 - val_accuracy: 0.7971
# Epoch 45/250
# 29/29 [==============================] - 4s 125ms/step - loss: 26.2957 - accuracy: 0.6626 - val_loss: 11.2673 - val_accuracy: 0.7993
# Epoch 46/250
# 29/29 [==============================] - 4s 126ms/step - loss: 25.3451 - accuracy: 0.6690 - val_loss: 11.1898 - val_accuracy: 0.7993
# Epoch 47/250
# 29/29 [==============================] - 4s 125ms/step - loss: 24.9792 - accuracy: 0.6634 - val_loss: 11.2087 - val_accuracy: 0.7982
# Epoch 48/250
# 29/29 [==============================] - 4s 123ms/step - loss: 24.8753 - accuracy: 0.6673 - val_loss: 11.0932 - val_accuracy: 0.7993
# Epoch 49/250
# 29/29 [==============================] - 4s 126ms/step - loss: 24.1862 - accuracy: 0.6754 - val_loss: 10.9796 - val_accuracy: 0.8016
# Epoch 50/250
# 29/29 [==============================] - 4s 127ms/step - loss: 23.3521 - accuracy: 0.6818 - val_loss: 10.7207 - val_accuracy: 0.8049
# Epoch 51/250
# 29/29 [==============================] - 4s 124ms/step - loss: 22.8140 - accuracy: 0.6854 - val_loss: 10.6440 - val_accuracy: 0.8016
# Epoch 52/250
# 29/29 [==============================] - 4s 125ms/step - loss: 22.7419 - accuracy: 0.6818 - val_loss: 10.8514 - val_accuracy: 0.7960
# Epoch 53/250
# 29/29 [==============================] - 4s 126ms/step - loss: 22.1648 - accuracy: 0.6895 - val_loss: 10.6196 - val_accuracy: 0.8038
# Epoch 54/250
# 29/29 [==============================] - 4s 125ms/step - loss: 22.0116 - accuracy: 0.6812 - val_loss: 10.7799 - val_accuracy: 0.7971
# Epoch 55/250
# 29/29 [==============================] - 4s 123ms/step - loss: 22.9699 - accuracy: 0.6751 - val_loss: 10.7144 - val_accuracy: 0.8004
# Epoch 56/250
# 29/29 [==============================] - 4s 126ms/step - loss: 22.5163 - accuracy: 0.6784 - val_loss: 10.8730 - val_accuracy: 0.7927
# Epoch 57/250
# 29/29 [==============================] - 4s 123ms/step - loss: 22.4440 - accuracy: 0.6765 - val_loss: 10.8199 - val_accuracy: 0.7938
# Epoch 58/250
# 29/29 [==============================] - 4s 126ms/step - loss: 22.5557 - accuracy: 0.6748 - val_loss: 10.9014 - val_accuracy: 0.7927
# Epoch 59/250
# 29/29 [==============================] - 4s 126ms/step - loss: 22.5302 - accuracy: 0.6698 - val_loss: 10.9520 - val_accuracy: 0.7882
# Epoch 60/250
# 29/29 [==============================] - 4s 126ms/step - loss: 23.0728 - accuracy: 0.6704 - val_loss: 10.9551 - val_accuracy: 0.7927
# Epoch 61/250
# 29/29 [==============================] - 4s 127ms/step - loss: 23.3750 - accuracy: 0.6570 - val_loss: 11.3781 - val_accuracy: 0.7849
# Epoch 62/250
# 29/29 [==============================] - 4s 126ms/step - loss: 23.8888 - accuracy: 0.6454 - val_loss: 11.4670 - val_accuracy: 0.7827
# Epoch 63/250
# 29/29 [==============================] - 4s 126ms/step - loss: 24.3524 - accuracy: 0.6498 - val_loss: 11.1587 - val_accuracy: 0.7905
# Epoch 64/250
# 29/29 [==============================] - 4s 126ms/step - loss: 24.1853 - accuracy: 0.6604 - val_loss: 10.9469 - val_accuracy: 0.7949
# Epoch 65/250
# 29/29 [==============================] - 4s 125ms/step - loss: 23.9353 - accuracy: 0.6579 - val_loss: 11.1651 - val_accuracy: 0.7894
# Epoch 66/250
# 29/29 [==============================] - 4s 127ms/step - loss: 24.0124 - accuracy: 0.6581 - val_loss: 10.9470 - val_accuracy: 0.7960
# Epoch 67/250
# 29/29 [==============================] - 4s 126ms/step - loss: 23.8150 - accuracy: 0.6570 - val_loss: 11.0966 - val_accuracy: 0.7905
# Epoch 68/250
# 29/29 [==============================] - 4s 123ms/step - loss: 23.9627 - accuracy: 0.6548 - val_loss: 11.3599 - val_accuracy: 0.7894
# Epoch 69/250
# 29/29 [==============================] - 4s 125ms/step - loss: 23.8743 - accuracy: 0.6479 - val_loss: 11.3127 - val_accuracy: 0.7894
# Epoch 70/250
# 29/29 [==============================] - 4s 126ms/step - loss: 23.7582 - accuracy: 0.6520 - val_loss: 11.0267 - val_accuracy: 0.7949
# Epoch 71/250
# 29/29 [==============================] - 4s 126ms/step - loss: 23.0072 - accuracy: 0.6656 - val_loss: 10.7087 - val_accuracy: 0.8004
# Epoch 72/250
# 29/29 [==============================] - 4s 124ms/step - loss: 22.7241 - accuracy: 0.6690 - val_loss: 10.5397 - val_accuracy: 0.8038
# Epoch 73/250
# 29/29 [==============================] - 4s 125ms/step - loss: 21.9159 - accuracy: 0.6859 - val_loss: 10.2447 - val_accuracy: 0.8093
# Epoch 74/250
# 29/29 [==============================] - 4s 124ms/step - loss: 20.5479 - accuracy: 0.7057 - val_loss: 9.8875 - val_accuracy: 0.8115
# Epoch 75/250
# 29/29 [==============================] - 4s 124ms/step - loss: 19.4844 - accuracy: 0.7073 - val_loss: 10.0672 - val_accuracy: 0.8049
# Epoch 76/250
# 29/29 [==============================] - 4s 125ms/step - loss: 19.1820 - accuracy: 0.7054 - val_loss: 9.9925 - val_accuracy: 0.8093
# Epoch 77/250
# 29/29 [==============================] - 4s 126ms/step - loss: 18.2340 - accuracy: 0.7240 - val_loss: 9.3965 - val_accuracy: 0.8204
# Epoch 78/250
# 29/29 [==============================] - 4s 125ms/step - loss: 16.6982 - accuracy: 0.7437 - val_loss: 9.1601 - val_accuracy: 0.8226
# Epoch 79/250
# 29/29 [==============================] - 4s 125ms/step - loss: 15.5472 - accuracy: 0.7560 - val_loss: 9.0361 - val_accuracy: 0.8259
# Epoch 80/250
# 29/29 [==============================] - 4s 126ms/step - loss: 14.5641 - accuracy: 0.7665 - val_loss: 8.9362 - val_accuracy: 0.8215
# Epoch 81/250
# 29/29 [==============================] - 4s 124ms/step - loss: 13.8502 - accuracy: 0.7679 - val_loss: 9.0265 - val_accuracy: 0.8226
# Epoch 82/250
# 29/29 [==============================] - 4s 124ms/step - loss: 13.7087 - accuracy: 0.7657 - val_loss: 8.9235 - val_accuracy: 0.8182
# Epoch 83/250
# 29/29 [==============================] - 4s 126ms/step - loss: 13.5881 - accuracy: 0.7638 - val_loss: 8.9760 - val_accuracy: 0.8137
# Epoch 84/250
# 29/29 [==============================] - 4s 125ms/step - loss: 13.8115 - accuracy: 0.7574 - val_loss: 9.1113 - val_accuracy: 0.8093
# Epoch 85/250
# 29/29 [==============================] - 4s 124ms/step - loss: 13.9793 - accuracy: 0.7543 - val_loss: 8.9974 - val_accuracy: 0.8104
# Epoch 86/250
# 29/29 [==============================] - 4s 126ms/step - loss: 13.8225 - accuracy: 0.7565 - val_loss: 9.0187 - val_accuracy: 0.8071
# Epoch 87/250
# 29/29 [==============================] - 4s 123ms/step - loss: 14.1089 - accuracy: 0.7474 - val_loss: 9.0943 - val_accuracy: 0.8027
# Epoch 88/250
# 29/29 [==============================] - 4s 125ms/step - loss: 14.0291 - accuracy: 0.7482 - val_loss: 9.0170 - val_accuracy: 0.8027
# Epoch 89/250
# 29/29 [==============================] - 4s 125ms/step - loss: 14.1969 - accuracy: 0.7443 - val_loss: 9.1892 - val_accuracy: 0.8004
# Epoch 90/250
# 29/29 [==============================] - 4s 124ms/step - loss: 14.6412 - accuracy: 0.7374 - val_loss: 9.2752 - val_accuracy: 0.7982
# Epoch 91/250
# 29/29 [==============================] - 4s 126ms/step - loss: 14.7248 - accuracy: 0.7276 - val_loss: 9.5501 - val_accuracy: 0.7971
# Epoch 92/250
# 29/29 [==============================] - 4s 126ms/step - loss: 15.3321 - accuracy: 0.7254 - val_loss: 9.2537 - val_accuracy: 0.8016
# Epoch 93/250
# 29/29 [==============================] - 4s 127ms/step - loss: 15.3258 - accuracy: 0.7237 - val_loss: 9.4844 - val_accuracy: 0.7993
# Epoch 94/250
# 29/29 [==============================] - 4s 123ms/step - loss: 16.0699 - accuracy: 0.7079 - val_loss: 9.6254 - val_accuracy: 0.8004
# Epoch 95/250
# 29/29 [==============================] - 4s 126ms/step - loss: 16.6642 - accuracy: 0.7135 - val_loss: 9.5427 - val_accuracy: 0.8004
# Epoch 96/250
# 29/29 [==============================] - 4s 125ms/step - loss: 16.9055 - accuracy: 0.7037 - val_loss: 9.7437 - val_accuracy: 0.7982
# Epoch 97/250
# 29/29 [==============================] - 4s 122ms/step - loss: 17.9664 - accuracy: 0.7009 - val_loss: 9.8575 - val_accuracy: 0.7960
# Epoch 98/250
# 29/29 [==============================] - 4s 126ms/step - loss: 18.8156 - accuracy: 0.6837 - val_loss: 10.2001 - val_accuracy: 0.7949
# Epoch 99/250
# 29/29 [==============================] - 4s 126ms/step - loss: 20.6557 - accuracy: 0.6701 - val_loss: 10.3415 - val_accuracy: 0.7916
# Epoch 100/250
# 29/29 [==============================] - 4s 127ms/step - loss: 21.6853 - accuracy: 0.6559 - val_loss: 10.5300 - val_accuracy: 0.7916
# Epoch 101/250
# 29/29 [==============================] - 4s 124ms/step - loss: 22.5677 - accuracy: 0.6531 - val_loss: 10.6917 - val_accuracy: 0.7894
# Epoch 102/250
# 29/29 [==============================] - 4s 127ms/step - loss: 23.7868 - accuracy: 0.6465 - val_loss: 10.6854 - val_accuracy: 0.7882
# Epoch 103/250
# 29/29 [==============================] - 4s 124ms/step - loss: 26.0131 - accuracy: 0.6237 - val_loss: 11.0897 - val_accuracy: 0.7827
# Epoch 104/250
# 29/29 [==============================] - 4s 127ms/step - loss: 27.1021 - accuracy: 0.6165 - val_loss: 11.1494 - val_accuracy: 0.7838
# Epoch 105/250
# 29/29 [==============================] - 4s 126ms/step - loss: 27.6527 - accuracy: 0.6115 - val_loss: 11.3921 - val_accuracy: 0.7882
# Epoch 106/250
# 29/29 [==============================] - 4s 125ms/step - loss: 28.8942 - accuracy: 0.6034 - val_loss: 11.3152 - val_accuracy: 0.7882
# Epoch 107/250
# 29/29 [==============================] - 4s 126ms/step - loss: 28.1057 - accuracy: 0.6092 - val_loss: 10.9438 - val_accuracy: 0.7927
# Epoch 108/250
# 29/29 [==============================] - 4s 125ms/step - loss: 26.2753 - accuracy: 0.6312 - val_loss: 10.6845 - val_accuracy: 0.8004
# Epoch 109/250
# 29/29 [==============================] - 4s 126ms/step - loss: 24.6972 - accuracy: 0.6415 - val_loss: 10.3935 - val_accuracy: 0.8016
# Epoch 110/250
# 29/29 [==============================] - 4s 126ms/step - loss: 22.4588 - accuracy: 0.6695 - val_loss: 10.0427 - val_accuracy: 0.8093
# Epoch 111/250
# 29/29 [==============================] - 4s 122ms/step - loss: 20.4068 - accuracy: 0.6951 - val_loss: 9.7203 - val_accuracy: 0.8193
# Epoch 112/250
# 29/29 [==============================] - 4s 126ms/step - loss: 17.8462 - accuracy: 0.7285 - val_loss: 9.3794 - val_accuracy: 0.8259
# Epoch 113/250
# 29/29 [==============================] - 4s 126ms/step - loss: 14.7841 - accuracy: 0.7618 - val_loss: 9.1932 - val_accuracy: 0.8315
# Epoch 114/250
# 29/29 [==============================] - 4s 125ms/step - loss: 12.7939 - accuracy: 0.7927 - val_loss: 8.9270 - val_accuracy: 0.8348
# Epoch 115/250
# 29/29 [==============================] - 4s 126ms/step - loss: 10.8367 - accuracy: 0.8121 - val_loss: 8.8461 - val_accuracy: 0.8370
# Epoch 116/250
# 29/29 [==============================] - 4s 127ms/step - loss: 9.6317 - accuracy: 0.8285 - val_loss: 8.5836 - val_accuracy: 0.8348
# Epoch 117/250
# 29/29 [==============================] - 4s 126ms/step - loss: 9.8820 - accuracy: 0.8249 - val_loss: 8.4547 - val_accuracy: 0.8359
# Epoch 118/250
# 29/29 [==============================] - 4s 122ms/step - loss: 9.3616 - accuracy: 0.8346 - val_loss: 8.4267 - val_accuracy: 0.8359
# Epoch 119/250
# 29/29 [==============================] - 4s 127ms/step - loss: 8.9513 - accuracy: 0.8313 - val_loss: 8.2976 - val_accuracy: 0.8337
# Epoch 120/250
# 29/29 [==============================] - 4s 128ms/step - loss: 9.2129 - accuracy: 0.8296 - val_loss: 8.1850 - val_accuracy: 0.8326
# Epoch 121/250
# 29/29 [==============================] - 4s 126ms/step - loss: 9.3511 - accuracy: 0.8235 - val_loss: 8.1239 - val_accuracy: 0.8337
# Epoch 122/250
# 29/29 [==============================] - 4s 125ms/step - loss: 9.2481 - accuracy: 0.8288 - val_loss: 8.1185 - val_accuracy: 0.8326
# Epoch 123/250
# 29/29 [==============================] - 4s 124ms/step - loss: 8.6932 - accuracy: 0.8288 - val_loss: 8.0653 - val_accuracy: 0.8315
# Epoch 124/250
# 29/29 [==============================] - 4s 122ms/step - loss: 8.5629 - accuracy: 0.8271 - val_loss: 7.9809 - val_accuracy: 0.8293
# Epoch 125/250
# 29/29 [==============================] - 4s 127ms/step - loss: 8.9764 - accuracy: 0.8224 - val_loss: 7.9928 - val_accuracy: 0.8237
# Epoch 126/250
# 29/29 [==============================] - 4s 126ms/step - loss: 9.2275 - accuracy: 0.8149 - val_loss: 7.9507 - val_accuracy: 0.8271
# Epoch 127/250
# 29/29 [==============================] - 4s 123ms/step - loss: 9.2287 - accuracy: 0.8116 - val_loss: 8.0001 - val_accuracy: 0.8215
# Epoch 128/250
# 29/29 [==============================] - 4s 126ms/step - loss: 9.7751 - accuracy: 0.7996 - val_loss: 8.1164 - val_accuracy: 0.8226
# Epoch 129/250
# 29/29 [==============================] - 4s 124ms/step - loss: 9.6686 - accuracy: 0.8013 - val_loss: 8.0112 - val_accuracy: 0.8226
# Epoch 130/250
# 29/29 [==============================] - 4s 123ms/step - loss: 9.4289 - accuracy: 0.8024 - val_loss: 7.9218 - val_accuracy: 0.8237
# Epoch 131/250
# 29/29 [==============================] - 4s 127ms/step - loss: 9.4823 - accuracy: 0.8054 - val_loss: 7.8834 - val_accuracy: 0.8259
# Epoch 132/250
# 29/29 [==============================] - 4s 123ms/step - loss: 9.4994 - accuracy: 0.7957 - val_loss: 8.0451 - val_accuracy: 0.8226
# Epoch 133/250
# 29/29 [==============================] - 4s 126ms/step - loss: 10.1951 - accuracy: 0.7824 - val_loss: 8.2249 - val_accuracy: 0.8160
# Epoch 134/250
# 29/29 [==============================] - 4s 121ms/step - loss: 10.5555 - accuracy: 0.7760 - val_loss: 8.2093 - val_accuracy: 0.8126
# Epoch 135/250
# 29/29 [==============================] - 4s 121ms/step - loss: 10.5632 - accuracy: 0.7727 - val_loss: 8.1837 - val_accuracy: 0.8160
# Epoch 136/250
# 29/29 [==============================] - 4s 126ms/step - loss: 10.6130 - accuracy: 0.7754 - val_loss: 8.1066 - val_accuracy: 0.8193
# Epoch 137/250
# 29/29 [==============================] - 4s 127ms/step - loss: 10.8089 - accuracy: 0.7765 - val_loss: 8.1735 - val_accuracy: 0.8160
# Epoch 138/250
# 29/29 [==============================] - 4s 127ms/step - loss: 10.7897 - accuracy: 0.7696 - val_loss: 8.4937 - val_accuracy: 0.8093
# Epoch 139/250
# 29/29 [==============================] - 4s 127ms/step - loss: 11.6938 - accuracy: 0.7510 - val_loss: 8.7686 - val_accuracy: 0.8104
# Epoch 140/250
# 29/29 [==============================] - 4s 126ms/step - loss: 12.1799 - accuracy: 0.7407 - val_loss: 9.0275 - val_accuracy: 0.8071
# Epoch 141/250
# 29/29 [==============================] - 4s 123ms/step - loss: 12.3346 - accuracy: 0.7365 - val_loss: 8.8785 - val_accuracy: 0.8071
# Epoch 142/250
# 29/29 [==============================] - 4s 123ms/step - loss: 12.3435 - accuracy: 0.7382 - val_loss: 9.1284 - val_accuracy: 0.8038
# Epoch 143/250
# 29/29 [==============================] - 4s 119ms/step - loss: 13.3686 - accuracy: 0.7201 - val_loss: 9.5762 - val_accuracy: 0.7938
# Epoch 144/250
# 29/29 [==============================] - 4s 126ms/step - loss: 14.6485 - accuracy: 0.7062 - val_loss: 9.7349 - val_accuracy: 0.7905
# Epoch 145/250
# 29/29 [==============================] - 4s 127ms/step - loss: 15.3710 - accuracy: 0.6993 - val_loss: 9.7572 - val_accuracy: 0.7882
# Epoch 146/250
# 29/29 [==============================] - 4s 127ms/step - loss: 15.9030 - accuracy: 0.6904 - val_loss: 9.9626 - val_accuracy: 0.7927
# Epoch 147/250
# 29/29 [==============================] - 4s 121ms/step - loss: 17.3355 - accuracy: 0.6784 - val_loss: 10.1029 - val_accuracy: 0.7905
# Epoch 148/250
# 29/29 [==============================] - 4s 126ms/step - loss: 18.7376 - accuracy: 0.6684 - val_loss: 10.6353 - val_accuracy: 0.7882
# Epoch 149/250
# 29/29 [==============================] - 4s 125ms/step - loss: 21.5940 - accuracy: 0.6401 - val_loss: 11.1287 - val_accuracy: 0.7860
# Epoch 150/250
# 29/29 [==============================] - 4s 124ms/step - loss: 23.5400 - accuracy: 0.6248 - val_loss: 11.2908 - val_accuracy: 0.7816
# Epoch 151/250
# 29/29 [==============================] - 4s 125ms/step - loss: 24.8646 - accuracy: 0.6159 - val_loss: 11.2037 - val_accuracy: 0.7871
# Epoch 152/250
# 29/29 [==============================] - 4s 127ms/step - loss: 26.5325 - accuracy: 0.6092 - val_loss: 10.9662 - val_accuracy: 0.7894
# Epoch 153/250
# 29/29 [==============================] - 4s 123ms/step - loss: 26.7708 - accuracy: 0.6112 - val_loss: 10.8181 - val_accuracy: 0.7916
# Epoch 154/250
# 29/29 [==============================] - 4s 126ms/step - loss: 27.2074 - accuracy: 0.6081 - val_loss: 10.8587 - val_accuracy: 0.7949
# Epoch 155/250
# 29/29 [==============================] - 4s 124ms/step - loss: 27.2481 - accuracy: 0.6076 - val_loss: 10.8371 - val_accuracy: 0.7960
# Epoch 156/250
# 29/29 [==============================] - 4s 126ms/step - loss: 25.8289 - accuracy: 0.6184 - val_loss: 10.6213 - val_accuracy: 0.7949
# Epoch 157/250
# 29/29 [==============================] - 4s 125ms/step - loss: 24.2999 - accuracy: 0.6354 - val_loss: 9.9039 - val_accuracy: 0.8149
# Epoch 158/250
# 29/29 [==============================] - 4s 127ms/step - loss: 21.0966 - accuracy: 0.6773 - val_loss: 9.4490 - val_accuracy: 0.8193
# Epoch 159/250
# 29/29 [==============================] - 4s 124ms/step - loss: 17.8163 - accuracy: 0.7176 - val_loss: 8.9887 - val_accuracy: 0.8326
# Epoch 160/250
# 29/29 [==============================] - 4s 125ms/step - loss: 15.1856 - accuracy: 0.7501 - val_loss: 8.7988 - val_accuracy: 0.8381
# Epoch 161/250
# 29/29 [==============================] - 4s 122ms/step - loss: 12.7761 - accuracy: 0.7840 - val_loss: 8.7890 - val_accuracy: 0.8359
# Epoch 162/250
# 29/29 [==============================] - 4s 125ms/step - loss: 9.9008 - accuracy: 0.8249 - val_loss: 8.6893 - val_accuracy: 0.8404
# Epoch 163/250
# 29/29 [==============================] - 4s 127ms/step - loss: 7.6713 - accuracy: 0.8596 - val_loss: 8.4896 - val_accuracy: 0.8437
# Epoch 164/250
# 29/29 [==============================] - 4s 126ms/step - loss: 6.7014 - accuracy: 0.8760 - val_loss: 8.3247 - val_accuracy: 0.8392
# Epoch 165/250
# 29/29 [==============================] - 4s 124ms/step - loss: 7.0635 - accuracy: 0.8674 - val_loss: 8.2561 - val_accuracy: 0.8370
# Epoch 166/250
# 29/29 [==============================] - 4s 124ms/step - loss: 6.8560 - accuracy: 0.8688 - val_loss: 8.1173 - val_accuracy: 0.8404
# Epoch 167/250
# 29/29 [==============================] - 4s 124ms/step - loss: 6.7661 - accuracy: 0.8694 - val_loss: 8.1069 - val_accuracy: 0.8370
# Epoch 168/250
# 29/29 [==============================] - 4s 125ms/step - loss: 6.7258 - accuracy: 0.8674 - val_loss: 8.0344 - val_accuracy: 0.8381
# Epoch 169/250
# 29/29 [==============================] - 4s 126ms/step - loss: 6.5785 - accuracy: 0.8671 - val_loss: 7.9909 - val_accuracy: 0.8381
# Epoch 170/250
# 29/29 [==============================] - 4s 126ms/step - loss: 6.4456 - accuracy: 0.8708 - val_loss: 7.8552 - val_accuracy: 0.8381
# Epoch 171/250
# 29/29 [==============================] - 4s 124ms/step - loss: 6.6513 - accuracy: 0.8610 - val_loss: 7.8191 - val_accuracy: 0.8404
# Epoch 172/250
# 29/29 [==============================] - 4s 126ms/step - loss: 6.5002 - accuracy: 0.8621 - val_loss: 7.7470 - val_accuracy: 0.8370
# Epoch 173/250
# 29/29 [==============================] - 4s 125ms/step - loss: 6.4029 - accuracy: 0.8646 - val_loss: 7.6569 - val_accuracy: 0.8326
# Epoch 174/250
# 29/29 [==============================] - 4s 125ms/step - loss: 6.1778 - accuracy: 0.8702 - val_loss: 7.6534 - val_accuracy: 0.8359
# Epoch 175/250
# 29/29 [==============================] - 4s 127ms/step - loss: 6.4094 - accuracy: 0.8588 - val_loss: 7.6345 - val_accuracy: 0.8315
# Epoch 176/250
# 29/29 [==============================] - 4s 126ms/step - loss: 6.6475 - accuracy: 0.8491 - val_loss: 7.6770 - val_accuracy: 0.8326
# Epoch 177/250
# 29/29 [==============================] - 4s 126ms/step - loss: 6.5395 - accuracy: 0.8521 - val_loss: 7.5771 - val_accuracy: 0.8315
# Epoch 178/250
# 29/29 [==============================] - 4s 125ms/step - loss: 6.4820 - accuracy: 0.8541 - val_loss: 7.5004 - val_accuracy: 0.8370
# Epoch 179/250
# 29/29 [==============================] - 4s 127ms/step - loss: 6.6118 - accuracy: 0.8477 - val_loss: 7.5739 - val_accuracy: 0.8337
# Epoch 180/250
# 29/29 [==============================] - 4s 126ms/step - loss: 6.8950 - accuracy: 0.8407 - val_loss: 7.5558 - val_accuracy: 0.8337
# Epoch 181/250
# 29/29 [==============================] - 4s 124ms/step - loss: 7.2019 - accuracy: 0.8346 - val_loss: 7.6306 - val_accuracy: 0.8326
# Epoch 182/250
# 29/29 [==============================] - 4s 121ms/step - loss: 7.2739 - accuracy: 0.8319 - val_loss: 7.6057 - val_accuracy: 0.8359
# Epoch 183/250
# 29/29 [==============================] - 4s 127ms/step - loss: 7.0424 - accuracy: 0.8355 - val_loss: 7.4042 - val_accuracy: 0.8392
# Epoch 184/250
# 29/29 [==============================] - 4s 125ms/step - loss: 6.5466 - accuracy: 0.8435 - val_loss: 7.3821 - val_accuracy: 0.8381
# Epoch 185/250
# 29/29 [==============================] - 4s 124ms/step - loss: 6.5691 - accuracy: 0.8491 - val_loss: 7.3695 - val_accuracy: 0.8359
# Epoch 186/250
# 29/29 [==============================] - 4s 125ms/step - loss: 6.5614 - accuracy: 0.8416 - val_loss: 7.4273 - val_accuracy: 0.8348
# Epoch 187/250
# 29/29 [==============================] - 4s 126ms/step - loss: 6.4396 - accuracy: 0.8419 - val_loss: 7.3346 - val_accuracy: 0.8337
# Epoch 188/250
# 29/29 [==============================] - 4s 125ms/step - loss: 6.4646 - accuracy: 0.8455 - val_loss: 7.2133 - val_accuracy: 0.8404
# Epoch 189/250
# 29/29 [==============================] - 4s 126ms/step - loss: 6.3154 - accuracy: 0.8499 - val_loss: 7.1694 - val_accuracy: 0.8404
# Epoch 190/250
# 29/29 [==============================] - 4s 123ms/step - loss: 6.1837 - accuracy: 0.8513 - val_loss: 7.1746 - val_accuracy: 0.8404
# Epoch 191/250
# 29/29 [==============================] - 4s 125ms/step - loss: 6.2458 - accuracy: 0.8521 - val_loss: 7.1574 - val_accuracy: 0.8370
# Epoch 192/250
# 29/29 [==============================] - 4s 126ms/step - loss: 6.1608 - accuracy: 0.8494 - val_loss: 7.1578 - val_accuracy: 0.8337
# Epoch 193/250
# 29/29 [==============================] - 4s 126ms/step - loss: 6.3943 - accuracy: 0.8402 - val_loss: 7.1285 - val_accuracy: 0.8359
# Epoch 194/250
# 29/29 [==============================] - 4s 125ms/step - loss: 6.5087 - accuracy: 0.8371 - val_loss: 7.1597 - val_accuracy: 0.8359
# Epoch 195/250
# 29/29 [==============================] - 4s 124ms/step - loss: 6.6648 - accuracy: 0.8324 - val_loss: 7.1845 - val_accuracy: 0.8359
# Epoch 196/250
# 29/29 [==============================] - 4s 125ms/step - loss: 6.8824 - accuracy: 0.8268 - val_loss: 7.3267 - val_accuracy: 0.8282
# Epoch 197/250
# 29/29 [==============================] - 4s 124ms/step - loss: 6.9989 - accuracy: 0.8260 - val_loss: 7.3329 - val_accuracy: 0.8293
# Epoch 198/250
# 29/29 [==============================] - 4s 124ms/step - loss: 6.9796 - accuracy: 0.8260 - val_loss: 7.2175 - val_accuracy: 0.8304
# Epoch 199/250
# 29/29 [==============================] - 4s 123ms/step - loss: 6.8905 - accuracy: 0.8243 - val_loss: 7.4194 - val_accuracy: 0.8204
# Epoch 200/250
# 29/29 [==============================] - 4s 126ms/step - loss: 7.6556 - accuracy: 0.8068 - val_loss: 7.6530 - val_accuracy: 0.8171
# Epoch 201/250
# 29/29 [==============================] - 4s 126ms/step - loss: 8.2077 - accuracy: 0.7941 - val_loss: 7.7504 - val_accuracy: 0.8171
# Epoch 202/250
# 29/29 [==============================] - 4s 127ms/step - loss: 7.9638 - accuracy: 0.8068 - val_loss: 7.6738 - val_accuracy: 0.8182
# Epoch 203/250
# 29/29 [==============================] - 4s 123ms/step - loss: 8.3022 - accuracy: 0.7996 - val_loss: 7.9185 - val_accuracy: 0.8115
# Epoch 204/250
# 29/29 [==============================] - 4s 126ms/step - loss: 8.7531 - accuracy: 0.7832 - val_loss: 8.1616 - val_accuracy: 0.8082
# Epoch 205/250
# 29/29 [==============================] - 4s 126ms/step - loss: 9.3456 - accuracy: 0.7738 - val_loss: 8.2396 - val_accuracy: 0.8093
# Epoch 206/250
# 29/29 [==============================] - 4s 124ms/step - loss: 9.2953 - accuracy: 0.7752 - val_loss: 8.2527 - val_accuracy: 0.8093
# Epoch 207/250
# 29/29 [==============================] - 4s 125ms/step - loss: 9.7542 - accuracy: 0.7749 - val_loss: 8.4398 - val_accuracy: 0.8082
# Epoch 208/250
# 29/29 [==============================] - 4s 126ms/step - loss: 10.1722 - accuracy: 0.7543 - val_loss: 8.9430 - val_accuracy: 0.8027
# Epoch 209/250
# 29/29 [==============================] - 4s 126ms/step - loss: 11.5057 - accuracy: 0.7337 - val_loss: 9.5128 - val_accuracy: 0.7960
# Epoch 210/250
# 29/29 [==============================] - 4s 124ms/step - loss: 13.3632 - accuracy: 0.7140 - val_loss: 9.9140 - val_accuracy: 0.7827
# Epoch 211/250
# 29/29 [==============================] - 4s 123ms/step - loss: 15.5260 - accuracy: 0.6932 - val_loss: 10.6295 - val_accuracy: 0.7794
# Epoch 212/250
# 29/29 [==============================] - 4s 126ms/step - loss: 17.5081 - accuracy: 0.6779 - val_loss: 10.8442 - val_accuracy: 0.7827
# Epoch 213/250
# 29/29 [==============================] - 4s 126ms/step - loss: 19.7520 - accuracy: 0.6673 - val_loss: 11.1510 - val_accuracy: 0.7805
# Epoch 214/250
# 29/29 [==============================] - 4s 127ms/step - loss: 21.8686 - accuracy: 0.6451 - val_loss: 11.2019 - val_accuracy: 0.7838
# Epoch 215/250
# 29/29 [==============================] - 4s 126ms/step - loss: 24.6891 - accuracy: 0.6198 - val_loss: 12.0956 - val_accuracy: 0.7838
# Epoch 216/250
# 29/29 [==============================] - 4s 125ms/step - loss: 28.5904 - accuracy: 0.5859 - val_loss: 11.9440 - val_accuracy: 0.7783
# Epoch 217/250
# 29/29 [==============================] - 4s 124ms/step - loss: 30.2883 - accuracy: 0.5759 - val_loss: 12.0391 - val_accuracy: 0.7749
# Epoch 218/250
# 29/29 [==============================] - 4s 125ms/step - loss: 29.8475 - accuracy: 0.5695 - val_loss: 12.2520 - val_accuracy: 0.7672
# Epoch 219/250
# 29/29 [==============================] - 4s 123ms/step - loss: 28.6247 - accuracy: 0.5856 - val_loss: 12.2643 - val_accuracy: 0.7738
# Epoch 220/250
# 29/29 [==============================] - 4s 127ms/step - loss: 25.5993 - accuracy: 0.6059 - val_loss: 11.9828 - val_accuracy: 0.7761
# Epoch 221/250
# 29/29 [==============================] - 4s 125ms/step - loss: 23.1647 - accuracy: 0.6195 - val_loss: 11.9942 - val_accuracy: 0.7816
# Epoch 222/250
# 29/29 [==============================] - 4s 127ms/step - loss: 22.1581 - accuracy: 0.6287 - val_loss: 11.7103 - val_accuracy: 0.7849
# Epoch 223/250
# 29/29 [==============================] - 4s 126ms/step - loss: 20.4807 - accuracy: 0.6398 - val_loss: 11.1047 - val_accuracy: 0.7938
# Epoch 224/250
# 29/29 [==============================] - 4s 126ms/step - loss: 18.1284 - accuracy: 0.6762 - val_loss: 10.2019 - val_accuracy: 0.8038
# Epoch 225/250
# 29/29 [==============================] - 4s 126ms/step - loss: 14.1167 - accuracy: 0.7307 - val_loss: 9.3148 - val_accuracy: 0.8259
# Epoch 226/250
# 29/29 [==============================] - 4s 127ms/step - loss: 10.8139 - accuracy: 0.7868 - val_loss: 8.6638 - val_accuracy: 0.8370
# Epoch 227/250
# 29/29 [==============================] - 4s 126ms/step - loss: 8.2017 - accuracy: 0.8324 - val_loss: 8.5364 - val_accuracy: 0.8381
# Epoch 228/250
# 29/29 [==============================] - 4s 127ms/step - loss: 6.3988 - accuracy: 0.8652 - val_loss: 8.2400 - val_accuracy: 0.8426
# Epoch 229/250
# 29/29 [==============================] - 4s 124ms/step - loss: 5.7575 - accuracy: 0.8830 - val_loss: 8.1478 - val_accuracy: 0.8470
# Epoch 230/250
# 29/29 [==============================] - 4s 127ms/step - loss: 5.4305 - accuracy: 0.8891 - val_loss: 8.0582 - val_accuracy: 0.8437
# Epoch 231/250
# 29/29 [==============================] - 4s 121ms/step - loss: 5.2898 - accuracy: 0.8908 - val_loss: 8.0122 - val_accuracy: 0.8437
# Epoch 232/250
# 29/29 [==============================] - 4s 124ms/step - loss: 5.2744 - accuracy: 0.8874 - val_loss: 7.9196 - val_accuracy: 0.8315
# Epoch 233/250
# 29/29 [==============================] - 4s 126ms/step - loss: 5.2856 - accuracy: 0.8891 - val_loss: 7.8874 - val_accuracy: 0.8459
# Epoch 234/250
# 29/29 [==============================] - 4s 124ms/step - loss: 4.8223 - accuracy: 0.8944 - val_loss: 7.7983 - val_accuracy: 0.8370
# Epoch 235/250
# 29/29 [==============================] - 4s 125ms/step - loss: 4.7510 - accuracy: 0.8949 - val_loss: 7.7440 - val_accuracy: 0.8381
# Epoch 236/250
# 29/29 [==============================] - 4s 124ms/step - loss: 4.8963 - accuracy: 0.8894 - val_loss: 7.6974 - val_accuracy: 0.8381
# Epoch 237/250
# 29/29 [==============================] - 4s 124ms/step - loss: 4.9695 - accuracy: 0.8827 - val_loss: 7.6459 - val_accuracy: 0.8381
# Epoch 238/250
# 29/29 [==============================] - 4s 121ms/step - loss: 5.0552 - accuracy: 0.8858 - val_loss: 7.6020 - val_accuracy: 0.8370
# Epoch 239/250
# 29/29 [==============================] - 4s 125ms/step - loss: 4.6597 - accuracy: 0.8938 - val_loss: 7.5690 - val_accuracy: 0.8392
# Epoch 240/250
# 29/29 [==============================] - 4s 126ms/step - loss: 4.5311 - accuracy: 0.8936 - val_loss: 7.5190 - val_accuracy: 0.8348
# Epoch 241/250
# 29/29 [==============================] - 4s 127ms/step - loss: 4.4453 - accuracy: 0.8936 - val_loss: 7.4926 - val_accuracy: 0.8337
# Epoch 242/250
# 29/29 [==============================] - 4s 123ms/step - loss: 4.2739 - accuracy: 0.8969 - val_loss: 7.4787 - val_accuracy: 0.8404
# Epoch 243/250
# 29/29 [==============================] - 4s 127ms/step - loss: 4.1813 - accuracy: 0.8949 - val_loss: 7.4238 - val_accuracy: 0.8293
# Epoch 244/250
# 29/29 [==============================] - 4s 124ms/step - loss: 4.3126 - accuracy: 0.8944 - val_loss: 7.3876 - val_accuracy: 0.8293
# Epoch 245/250
# 29/29 [==============================] - 4s 126ms/step - loss: 4.3767 - accuracy: 0.8916 - val_loss: 7.3726 - val_accuracy: 0.8326
# Epoch 246/250
# 29/29 [==============================] - 4s 122ms/step - loss: 4.3249 - accuracy: 0.8877 - val_loss: 7.3343 - val_accuracy: 0.8293
# Epoch 247/250
# 29/29 [==============================] - 4s 124ms/step - loss: 4.5303 - accuracy: 0.8858 - val_loss: 7.3049 - val_accuracy: 0.8315
# Epoch 248/250
# 29/29 [==============================] - 4s 124ms/step - loss: 4.5001 - accuracy: 0.8830 - val_loss: 7.3009 - val_accuracy: 0.8392
# Epoch 249/250
# 29/29 [==============================] - 4s 122ms/step - loss: 4.2614 - accuracy: 0.8855 - val_loss: 7.2526 - val_accuracy: 0.8337
# Epoch 250/250
# 29/29 [==============================] - 4s 123ms/step - loss: 4.0621 - accuracy: 0.8913 - val_loss: 7.2189 - val_accuracy: 0.8337
# run epochs:  250
# 6/6 [==============================] - 1s 206ms/step - loss: 7.2368 - accuracy: 0.8227
# classification report: resnet50_NOdataAug_dropoutFirst007no_synth_train_val_ds_trainVal
#                precision    recall  f1-score   support
#
#      Bedroom       0.91      0.92      0.92       219
#     Bathroom       0.87      0.90      0.88        89
#      Dinning       0.79      0.80      0.79       199
#   Livingroom       0.82      0.81      0.82       227
#      Kitchen       0.78      0.76      0.77       168
#
#     accuracy                           0.83       902
#    macro avg       0.83      0.84      0.84       902
# weighted avg       0.83      0.83      0.83       902
# 6/6 [==============================] - 1s 120ms/step - loss: 7.2368 - accuracy: 0.8227
# classification report: resnet50_NOdataAug_dropoutFirst007no_synth_train_val_ds_trainTest
#                precision    recall  f1-score   support
#
#      Bedroom       0.88      0.87      0.87       152
#     Bathroom       0.88      0.94      0.91       140
#      Dinning       0.77      0.78      0.77       147
#   Livingroom       0.82      0.76      0.79       161
#      Kitchen       0.77      0.77      0.77       150
#
#     accuracy                           0.82       750
#    macro avg       0.82      0.82      0.82       750
# weighted avg       0.82      0.82      0.82       750
