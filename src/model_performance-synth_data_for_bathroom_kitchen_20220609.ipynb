# %% [markdown]
# # Studying a model performance with synthetic data
#
# Synthetic data have been created for each class, using as input the pictures that all models misclassify. The idea is the following: Maybe having more pics similar to the misclassified ones we can improve the performance of the model in that areas.
#
# - There are a test set with 150 real pics of each class.
# - The remainder are split into train/val set (80% train)
# - For the train set, 480 fake pics have been added to the bathroom class, 250 to the kitchen class (the minority classes), so we have a more balanced dataset
#
#
# - The study of what pics were generated synthetically can be found here => https://github.com/albertovpd/viu_tfm-deep_vision_classification/tree/synthetic_data_study
#
# - They were created using the pytorch implementation of this repo => https://github.com/mit-han-lab/data-efficient-gans

# %%
# Google Drive stuff
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Thu Jun  9 13:23:26 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    25W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# tf
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# - libs

# %%
# %tensorflow_version 2.x
# batch ingestion of pics without pickle
from tensorflow.keras.preprocessing import image_dataset_from_directory

# nns
from tensorflow.keras.applications import ResNet50 

from tensorflow.keras import Model
from tensorflow.keras.models import load_model # Sequential
from tensorflow.keras import layers 

# optimization
from tensorflow.keras.optimizers import SGD #Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy, categorical_crossentropy
from tensorflow.keras.callbacks import EarlyStopping

# nn architectures, metrics, viz & reports => written in my_functions202202 file
import sys
sys.path.append("/content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/src")
from my_functions202202 import generic_last_2layers, plotting_model, model_evaluation, classification_report_pic, confusion_matrix_report

import numpy as np
# %matplotlib inline

# navigating through folder
import os

# %% [markdown]
# - paths

# %%
base_folder = "/content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/"
train_folder = base_folder + "input/dataset_synth_data-augmented_bathroom_kitchen_20220608/train_ds/"
val_folder = base_folder + "input/dataset_synth_data-augmented_bathroom_kitchen_20220608/val_ds/"
test_folder = base_folder+"input/dataset_synth_data-augmented_bathroom_kitchen_20220608/test_ds/"

src_folder =  base_folder+"src/"
output_folder = base_folder + "/output/"

# %% [markdown]
# - functions

# %%
#my_functions202202.py

# %% [markdown]
# - common parameters

# %%
# resolution changed to 224 for every pic
image_size = (224,224)
batch_size = 128
epochs = 250
opt = SGD(momentum=0.9)

# %%
base_model_resnet50 = ResNet50(include_top=False, weights='imagenet', input_shape=(image_size[0], image_size[1], 3), classes = 5) 
models_dict = {"resnet50_NOdataAug_dropoutFirst007": 
         generic_last_2layers(data_augmentation= None, nn=base_model_resnet50, neurons_final_layer=5, dropout_layers=True,  dropout_position="first",  dropout_percent = 0.07)
         }
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
train_ds = image_dataset_from_directory(
        train_folder,
        class_names=["Bedroom","Bathroom","Dinning","Livingroom","Kitchen"],
        seed=None,
        validation_split=None, 
        subset=None,
        image_size= image_size,
        batch_size= batch_size,
        color_mode='rgb',
        shuffle=False 
        )
# Out:
# Found 4338 files belonging to 5 classes.

# %%
val_ds = image_dataset_from_directory(
        val_folder,
        class_names=["Bedroom","Bathroom","Dinning","Livingroom","Kitchen"],
        seed=None,
        validation_split=None, 
        subset=None,
        image_size= image_size,
        batch_size= batch_size,
        color_mode='rgb',
        shuffle=False 
      )
# Out:
# Found 902 files belonging to 5 classes.

# %%
test_ds = image_dataset_from_directory(
    test_folder,
      class_names=["Bedroom","Bathroom","Dinning","Livingroom","Kitchen"],
      seed=None,
      validation_split=None, 
      subset=None,
      image_size= image_size,
      batch_size= batch_size,
      color_mode='rgb',
      shuffle=False 
  )
# Out:
# Found 750 files belonging to 5 classes.

# %%
class_names = train_ds.class_names
print(class_names)

# checking numbers non sense now because all have same volume
paths = ['train_ds/', 'val_ds/', "test_ds/"]
for p in paths:
    for dir,subdir,files in os.walk(base_folder + "input/dataset_synth_data-augmented_bathroom_kitchen/"+p):
        print(dir,' => ', p, str(len(files)))

# calling model
model_name, nn = list(models_dict.items())[0]
print("\n", model_name)
nn.summary()

nn.compile( optimizer = opt, #"adam", 
              loss=SparseCategoricalCrossentropy(from_logits=True) ,#'categorical_crossentropy', 
              metrics=['accuracy'] # "recall"
              )

# ====== USING VAL DATASET ======

history = nn.fit(
      train_ds,
      validation_data=val_ds,
      epochs=epochs,
      #callbacks = callbacks # <=== REMOVE CALLBACK for full results
      )

number_of_epochs_it_ran = len(history.history['loss']) 
print("run epochs: ",number_of_epochs_it_ran)
name = model_name+"-synth_data_for_bath_kitchen"
#models_dict[m].save(output_folder+name+".h5")

# saving model accuracy/loss graph
plotting_model(history,number_of_epochs_it_ran, name, output_folder, "val") 

# saving model metrics to json
evaluation = nn.evaluate(test_ds, batch_size=batch_size, return_dict=True)
model_evaluation(evaluation, output_folder, name+"_trainVal")

# get inferences
y_pred_val_float = nn.predict(val_ds)
y_pred_val = np.argmax(y_pred_val_float, axis=1)

# get real labels
y_target = tf.concat([y for x, y in val_ds], axis=0) 

# classification and confusion matrix reports
classification_report_pic(y_pred_val, y_target,  class_names, output_folder, name+"_trainVal")
confusion_matrix_report(y_pred_val, y_target, class_names, output_folder, name+"_trainVal")

# ====== USING TEST DATASET ======

# saving model metrics to json
evaluation_test = nn.evaluate(test_ds, batch_size=batch_size, return_dict=True)
model_evaluation(evaluation_test, output_folder, name+"_trainTest")

# get inferences
y_pred_test_float = nn.predict(test_ds)
y_pred_test = np.argmax(y_pred_test_float, axis=1)

# get real labels for val_ds
y_target_test = tf.concat([y for x, y in test_ds], axis=0) 

# classification and confusion matrix reports
classification_report_pic(y_pred_test, y_target_test,  class_names, output_folder, name+"_trainTest")
confusion_matrix_report(y_pred_test, y_target_test, class_names, output_folder, name+"_trainTest")
# Out:
# ['Bedroom', 'Bathroom', 'Dinning', 'Livingroom', 'Kitchen']
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/train_ds/  =>  train_ds/ 0
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/train_ds/Dinning  =>  train_ds/ 806
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/train_ds/Bedroom  =>  train_ds/ 878
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/train_ds/Kitchen  =>  train_ds/ 902
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/train_ds/Bathroom  =>  train_ds/ 844
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/train_ds/Livingroom  =>  train_ds/ 898
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/val_ds/  =>  val_ds/ 0
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/val_ds/Kitchen  =>  val_ds/ 163
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/val_ds/Bathroom  =>  val_ds/ 92
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/val_ds/Livingroom  =>  val_ds/ 225
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/val_ds/Bedroom  =>  val_ds/ 220
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/val_ds/Dinning  =>  val_ds/ 202
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/test_ds/  =>  test_ds/ 0
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/test_ds/Livingroom  =>  test_ds/ 150
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/test_ds/Dinning  =>  test_ds/ 150
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/test_ds/Kitchen  =>  test_ds/ 150
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/test_ds/Bedroom  =>  test_ds/ 150
# /content/drive/My Drive/2-Estudios/viu-master_ai/tfm-deep_vision/input/dataset_synth_data-augmented_bathroom_kitchen/test_ds/Bathroom  =>  test_ds/ 150
#
#  resnet50_NOdataAug_dropoutFirst007
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  dropout (Dropout)           (None, 7, 7, 2048)        0
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 5)                 10245
#
# =================================================================
# Total params: 23,597,957
# Trainable params: 10,245
# Non-trainable params: 23,587,712
# _________________________________________________________________
# Epoch 1/250
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 34/34 [==============================] - 889s 26s/step - loss: 63.1985 - accuracy: 0.4290 - val_loss: 218.1003 - val_accuracy: 0.2494
# Epoch 2/250
# 34/34 [==============================] - 13s 368ms/step - loss: 278.3768 - accuracy: 0.0083 - val_loss: 162.6062 - val_accuracy: 0.2018
# Epoch 3/250
# 34/34 [==============================] - 12s 357ms/step - loss: 209.8167 - accuracy: 0.1012 - val_loss: 53.7971 - val_accuracy: 0.4091
# Epoch 4/250
# 34/34 [==============================] - 12s 357ms/step - loss: 183.3895 - accuracy: 0.2619 - val_loss: 75.2379 - val_accuracy: 0.4945
# Epoch 5/250
# 34/34 [==============================] - 12s 359ms/step - loss: 88.3561 - accuracy: 0.4182 - val_loss: 35.1546 - val_accuracy: 0.5576
# Epoch 6/250
# 34/34 [==============================] - 12s 359ms/step - loss: 145.9693 - accuracy: 0.3073 - val_loss: 78.8533 - val_accuracy: 0.4290
# Epoch 7/250
# 34/34 [==============================] - 12s 359ms/step - loss: 93.1631 - accuracy: 0.3891 - val_loss: 37.7468 - val_accuracy: 0.5787
# Epoch 8/250
# 34/34 [==============================] - 12s 361ms/step - loss: 130.8373 - accuracy: 0.3525 - val_loss: 59.9874 - val_accuracy: 0.5233
# Epoch 9/250
# 34/34 [==============================] - 12s 359ms/step - loss: 87.3416 - accuracy: 0.4315 - val_loss: 30.3438 - val_accuracy: 0.6585
# Epoch 10/250
# 34/34 [==============================] - 12s 361ms/step - loss: 112.6331 - accuracy: 0.4094 - val_loss: 38.6705 - val_accuracy: 0.6330
# Epoch 11/250
# 34/34 [==============================] - 12s 353ms/step - loss: 83.7831 - accuracy: 0.4631 - val_loss: 23.3937 - val_accuracy: 0.7251
# Epoch 12/250
# 34/34 [==============================] - 12s 357ms/step - loss: 91.2622 - accuracy: 0.4583 - val_loss: 24.9684 - val_accuracy: 0.7206
# Epoch 13/250
# 34/34 [==============================] - 12s 359ms/step - loss: 78.9317 - accuracy: 0.4924 - val_loss: 21.4744 - val_accuracy: 0.7517
# Epoch 14/250
# 34/34 [==============================] - 12s 359ms/step - loss: 76.4646 - accuracy: 0.5060 - val_loss: 21.4903 - val_accuracy: 0.7539
# Epoch 15/250
# 34/34 [==============================] - 12s 357ms/step - loss: 69.1801 - accuracy: 0.5272 - val_loss: 20.0681 - val_accuracy: 0.7627
# Epoch 16/250
# 34/34 [==============================] - 12s 359ms/step - loss: 64.3358 - accuracy: 0.5482 - val_loss: 19.4029 - val_accuracy: 0.7672
# Epoch 17/250
# 34/34 [==============================] - 12s 365ms/step - loss: 59.4314 - accuracy: 0.5655 - val_loss: 18.6031 - val_accuracy: 0.7738
# Epoch 18/250
# 34/34 [==============================] - 12s 355ms/step - loss: 55.7929 - accuracy: 0.5809 - val_loss: 18.0564 - val_accuracy: 0.7749
# Epoch 19/250
# 34/34 [==============================] - 12s 356ms/step - loss: 51.0463 - accuracy: 0.6021 - val_loss: 17.6607 - val_accuracy: 0.7738
# Epoch 20/250
# 34/34 [==============================] - 12s 360ms/step - loss: 46.8149 - accuracy: 0.6194 - val_loss: 17.2297 - val_accuracy: 0.7783
# Epoch 21/250
# 34/34 [==============================] - 12s 358ms/step - loss: 45.4161 - accuracy: 0.6240 - val_loss: 16.9979 - val_accuracy: 0.7827
# Epoch 22/250
# 34/34 [==============================] - 12s 356ms/step - loss: 44.6829 - accuracy: 0.6224 - val_loss: 16.9819 - val_accuracy: 0.7805
# Epoch 23/250
# 34/34 [==============================] - 12s 364ms/step - loss: 43.7314 - accuracy: 0.6256 - val_loss: 16.6230 - val_accuracy: 0.7860
# Epoch 24/250
# 34/34 [==============================] - 12s 359ms/step - loss: 42.6557 - accuracy: 0.6266 - val_loss: 16.8821 - val_accuracy: 0.7860
# Epoch 25/250
# 34/34 [==============================] - 13s 369ms/step - loss: 42.9109 - accuracy: 0.6229 - val_loss: 17.0478 - val_accuracy: 0.7816
# Epoch 26/250
# 34/34 [==============================] - 12s 363ms/step - loss: 41.9398 - accuracy: 0.6256 - val_loss: 16.5891 - val_accuracy: 0.7860
# Epoch 27/250
# 34/34 [==============================] - 12s 363ms/step - loss: 41.1923 - accuracy: 0.6309 - val_loss: 16.6632 - val_accuracy: 0.7860
# Epoch 28/250
# 34/34 [==============================] - 12s 364ms/step - loss: 39.3087 - accuracy: 0.6390 - val_loss: 16.1605 - val_accuracy: 0.7916
# Epoch 29/250
# 34/34 [==============================] - 13s 371ms/step - loss: 38.4458 - accuracy: 0.6429 - val_loss: 15.9451 - val_accuracy: 0.7916
# Epoch 30/250
# 34/34 [==============================] - 13s 378ms/step - loss: 38.2943 - accuracy: 0.6392 - val_loss: 16.0956 - val_accuracy: 0.7871
# Epoch 31/250
# 34/34 [==============================] - 12s 358ms/step - loss: 37.2673 - accuracy: 0.6468 - val_loss: 15.9292 - val_accuracy: 0.7882
# Epoch 32/250
# 34/34 [==============================] - 12s 360ms/step - loss: 36.1567 - accuracy: 0.6515 - val_loss: 15.6042 - val_accuracy: 0.7882
# Epoch 33/250
# 34/34 [==============================] - 12s 364ms/step - loss: 36.5049 - accuracy: 0.6489 - val_loss: 15.4823 - val_accuracy: 0.7905
# Epoch 34/250
# 34/34 [==============================] - 12s 366ms/step - loss: 37.2247 - accuracy: 0.6432 - val_loss: 15.6440 - val_accuracy: 0.7905
# Epoch 35/250
# 34/34 [==============================] - 12s 364ms/step - loss: 37.0546 - accuracy: 0.6379 - val_loss: 15.5059 - val_accuracy: 0.7894
# Epoch 36/250
# 34/34 [==============================] - 12s 358ms/step - loss: 36.4448 - accuracy: 0.6459 - val_loss: 15.5405 - val_accuracy: 0.7882
# Epoch 37/250
# 34/34 [==============================] - 12s 361ms/step - loss: 35.0598 - accuracy: 0.6531 - val_loss: 15.1454 - val_accuracy: 0.7971
# Epoch 38/250
# 34/34 [==============================] - 12s 363ms/step - loss: 34.1841 - accuracy: 0.6581 - val_loss: 15.0454 - val_accuracy: 0.7982
# Epoch 39/250
# 34/34 [==============================] - 12s 364ms/step - loss: 33.0057 - accuracy: 0.6699 - val_loss: 14.6598 - val_accuracy: 0.7982
# Epoch 40/250
# 34/34 [==============================] - 12s 362ms/step - loss: 31.2330 - accuracy: 0.6800 - val_loss: 14.4301 - val_accuracy: 0.7971
# Epoch 41/250
# 34/34 [==============================] - 12s 362ms/step - loss: 30.5084 - accuracy: 0.6789 - val_loss: 14.4411 - val_accuracy: 0.7949
# Epoch 42/250
# 34/34 [==============================] - 12s 364ms/step - loss: 30.8160 - accuracy: 0.6782 - val_loss: 14.2569 - val_accuracy: 0.7960
# Epoch 43/250
# 34/34 [==============================] - 12s 358ms/step - loss: 30.3006 - accuracy: 0.6826 - val_loss: 14.1245 - val_accuracy: 0.8004
# Epoch 44/250
# 34/34 [==============================] - 12s 357ms/step - loss: 29.5909 - accuracy: 0.6860 - val_loss: 13.9352 - val_accuracy: 0.8004
# Epoch 45/250
# 34/34 [==============================] - 12s 359ms/step - loss: 29.7009 - accuracy: 0.6874 - val_loss: 13.9087 - val_accuracy: 0.8016
# Epoch 46/250
# 34/34 [==============================] - 12s 355ms/step - loss: 29.2990 - accuracy: 0.6837 - val_loss: 13.8559 - val_accuracy: 0.8027
# Epoch 47/250
# 34/34 [==============================] - 12s 353ms/step - loss: 28.9699 - accuracy: 0.6883 - val_loss: 13.7137 - val_accuracy: 0.8027
# Epoch 48/250
# 34/34 [==============================] - 12s 353ms/step - loss: 28.5782 - accuracy: 0.6851 - val_loss: 13.9788 - val_accuracy: 0.7960
# Epoch 49/250
# 34/34 [==============================] - 12s 349ms/step - loss: 28.7293 - accuracy: 0.6844 - val_loss: 13.8090 - val_accuracy: 0.7971
# Epoch 50/250
# 34/34 [==============================] - 12s 356ms/step - loss: 28.9960 - accuracy: 0.6819 - val_loss: 13.8653 - val_accuracy: 0.7971
# Epoch 51/250
# 34/34 [==============================] - 12s 353ms/step - loss: 28.6590 - accuracy: 0.6814 - val_loss: 13.6545 - val_accuracy: 0.8038
# Epoch 52/250
# 34/34 [==============================] - 12s 352ms/step - loss: 28.4779 - accuracy: 0.6840 - val_loss: 13.7825 - val_accuracy: 0.8016
# Epoch 53/250
# 34/34 [==============================] - 12s 353ms/step - loss: 28.1811 - accuracy: 0.6876 - val_loss: 13.3971 - val_accuracy: 0.8060
# Epoch 54/250
# 34/34 [==============================] - 12s 353ms/step - loss: 28.6505 - accuracy: 0.6851 - val_loss: 13.3737 - val_accuracy: 0.8071
# Epoch 55/250
# 34/34 [==============================] - 12s 356ms/step - loss: 28.5104 - accuracy: 0.6842 - val_loss: 13.5774 - val_accuracy: 0.8049
# Epoch 56/250
# 34/34 [==============================] - 12s 350ms/step - loss: 27.3552 - accuracy: 0.6962 - val_loss: 13.1875 - val_accuracy: 0.8071
# Epoch 57/250
# 34/34 [==============================] - 12s 357ms/step - loss: 26.7213 - accuracy: 0.6978 - val_loss: 13.2277 - val_accuracy: 0.8104
# Epoch 58/250
# 34/34 [==============================] - 12s 357ms/step - loss: 25.8066 - accuracy: 0.7061 - val_loss: 13.0160 - val_accuracy: 0.8082
# Epoch 59/250
# 34/34 [==============================] - 12s 354ms/step - loss: 25.6181 - accuracy: 0.7045 - val_loss: 12.9032 - val_accuracy: 0.8082
# Epoch 60/250
# 34/34 [==============================] - 12s 363ms/step - loss: 25.0021 - accuracy: 0.7070 - val_loss: 12.8586 - val_accuracy: 0.8060
# Epoch 61/250
# 34/34 [==============================] - 12s 358ms/step - loss: 24.7423 - accuracy: 0.7132 - val_loss: 12.6088 - val_accuracy: 0.8093
# Epoch 62/250
# 34/34 [==============================] - 12s 355ms/step - loss: 24.5733 - accuracy: 0.7123 - val_loss: 12.4264 - val_accuracy: 0.8137
# Epoch 63/250
# 34/34 [==============================] - 12s 356ms/step - loss: 24.2296 - accuracy: 0.7160 - val_loss: 12.4957 - val_accuracy: 0.8093
# Epoch 64/250
# 34/34 [==============================] - 12s 364ms/step - loss: 24.8532 - accuracy: 0.7130 - val_loss: 12.2079 - val_accuracy: 0.8126
# Epoch 65/250
# 34/34 [==============================] - 12s 366ms/step - loss: 24.5999 - accuracy: 0.7123 - val_loss: 12.3930 - val_accuracy: 0.8093
# Epoch 66/250
# 34/34 [==============================] - 12s 359ms/step - loss: 24.1668 - accuracy: 0.7155 - val_loss: 12.3971 - val_accuracy: 0.8115
# Epoch 67/250
# 34/34 [==============================] - 12s 357ms/step - loss: 23.4873 - accuracy: 0.7213 - val_loss: 12.1406 - val_accuracy: 0.8115
# Epoch 68/250
# 34/34 [==============================] - 12s 358ms/step - loss: 22.5078 - accuracy: 0.7342 - val_loss: 11.9689 - val_accuracy: 0.8160
# Epoch 69/250
# 34/34 [==============================] - 12s 354ms/step - loss: 21.4316 - accuracy: 0.7372 - val_loss: 11.9301 - val_accuracy: 0.8149
# Epoch 70/250
# 34/34 [==============================] - 12s 354ms/step - loss: 21.1764 - accuracy: 0.7397 - val_loss: 11.9831 - val_accuracy: 0.8082
# Epoch 71/250
# 34/34 [==============================] - 12s 357ms/step - loss: 21.1593 - accuracy: 0.7367 - val_loss: 11.8109 - val_accuracy: 0.8149
# Epoch 72/250
# 34/34 [==============================] - 12s 355ms/step - loss: 21.2187 - accuracy: 0.7404 - val_loss: 11.6561 - val_accuracy: 0.8149
# Epoch 73/250
# 34/34 [==============================] - 12s 354ms/step - loss: 21.1139 - accuracy: 0.7400 - val_loss: 11.8368 - val_accuracy: 0.8104
# Epoch 74/250
# 34/34 [==============================] - 12s 356ms/step - loss: 20.5862 - accuracy: 0.7411 - val_loss: 11.4968 - val_accuracy: 0.8171
# Epoch 75/250
# 34/34 [==============================] - 12s 350ms/step - loss: 20.8308 - accuracy: 0.7409 - val_loss: 11.5545 - val_accuracy: 0.8115
# Epoch 76/250
# 34/34 [==============================] - 12s 353ms/step - loss: 20.2846 - accuracy: 0.7432 - val_loss: 11.5692 - val_accuracy: 0.8115
# Epoch 77/250
# 34/34 [==============================] - 12s 355ms/step - loss: 19.6813 - accuracy: 0.7448 - val_loss: 11.5647 - val_accuracy: 0.8126
# Epoch 78/250
# 34/34 [==============================] - 12s 351ms/step - loss: 19.1255 - accuracy: 0.7552 - val_loss: 11.2456 - val_accuracy: 0.8215
# Epoch 79/250
# 34/34 [==============================] - 12s 358ms/step - loss: 18.5816 - accuracy: 0.7619 - val_loss: 11.2593 - val_accuracy: 0.8149
# Epoch 80/250
# 34/34 [==============================] - 12s 357ms/step - loss: 18.2780 - accuracy: 0.7568 - val_loss: 11.1921 - val_accuracy: 0.8149
# Epoch 81/250
# 34/34 [==============================] - 12s 358ms/step - loss: 18.2771 - accuracy: 0.7589 - val_loss: 11.0880 - val_accuracy: 0.8160
# Epoch 82/250
# 34/34 [==============================] - 12s 353ms/step - loss: 18.5976 - accuracy: 0.7494 - val_loss: 11.1081 - val_accuracy: 0.8149
# Epoch 83/250
# 34/34 [==============================] - 13s 388ms/step - loss: 18.1499 - accuracy: 0.7589 - val_loss: 10.9514 - val_accuracy: 0.8182
# Epoch 84/250
# 34/34 [==============================] - 12s 352ms/step - loss: 17.7400 - accuracy: 0.7644 - val_loss: 10.9961 - val_accuracy: 0.8193
# Epoch 85/250
# 34/34 [==============================] - 12s 360ms/step - loss: 17.3009 - accuracy: 0.7663 - val_loss: 10.9402 - val_accuracy: 0.8126
# Epoch 86/250
# 34/34 [==============================] - 12s 358ms/step - loss: 17.8776 - accuracy: 0.7550 - val_loss: 10.9715 - val_accuracy: 0.8137
# Epoch 87/250
# 34/34 [==============================] - 12s 354ms/step - loss: 18.6916 - accuracy: 0.7439 - val_loss: 11.0957 - val_accuracy: 0.8115
# Epoch 88/250
# 34/34 [==============================] - 12s 355ms/step - loss: 18.9993 - accuracy: 0.7388 - val_loss: 10.8695 - val_accuracy: 0.8171
# Epoch 89/250
# 34/34 [==============================] - 12s 357ms/step - loss: 19.8265 - accuracy: 0.7340 - val_loss: 10.8713 - val_accuracy: 0.8160
# Epoch 90/250
# 34/34 [==============================] - 12s 359ms/step - loss: 20.5590 - accuracy: 0.7303 - val_loss: 11.1061 - val_accuracy: 0.8137
# Epoch 91/250
# 34/34 [==============================] - 12s 358ms/step - loss: 20.9657 - accuracy: 0.7261 - val_loss: 10.9455 - val_accuracy: 0.8160
# Epoch 92/250
# 34/34 [==============================] - 12s 360ms/step - loss: 21.6488 - accuracy: 0.7218 - val_loss: 11.1084 - val_accuracy: 0.8160
# Epoch 93/250
# 34/34 [==============================] - 12s 358ms/step - loss: 22.2366 - accuracy: 0.7169 - val_loss: 11.2601 - val_accuracy: 0.8137
# Epoch 94/250
# 34/34 [==============================] - 12s 357ms/step - loss: 22.6517 - accuracy: 0.7107 - val_loss: 11.5564 - val_accuracy: 0.8093
# Epoch 95/250
# 34/34 [==============================] - 12s 357ms/step - loss: 23.8017 - accuracy: 0.6964 - val_loss: 11.7902 - val_accuracy: 0.8104
# Epoch 96/250
# 34/34 [==============================] - 12s 355ms/step - loss: 25.4651 - accuracy: 0.6872 - val_loss: 11.7767 - val_accuracy: 0.8104
# Epoch 97/250
# 34/34 [==============================] - 12s 355ms/step - loss: 25.6518 - accuracy: 0.6911 - val_loss: 11.4487 - val_accuracy: 0.8171
# Epoch 98/250
# 34/34 [==============================] - 12s 355ms/step - loss: 25.5963 - accuracy: 0.6950 - val_loss: 11.6307 - val_accuracy: 0.8137
# Epoch 99/250
# 34/34 [==============================] - 12s 357ms/step - loss: 26.3568 - accuracy: 0.6826 - val_loss: 11.9347 - val_accuracy: 0.8115
# Epoch 100/250
# 34/34 [==============================] - 12s 353ms/step - loss: 26.5174 - accuracy: 0.6803 - val_loss: 12.0049 - val_accuracy: 0.8115
# Epoch 101/250
# 34/34 [==============================] - 12s 358ms/step - loss: 27.2336 - accuracy: 0.6789 - val_loss: 12.0905 - val_accuracy: 0.8126
# Epoch 102/250
# 34/34 [==============================] - 12s 357ms/step - loss: 27.1060 - accuracy: 0.6798 - val_loss: 12.0988 - val_accuracy: 0.8115
# Epoch 103/250
# 34/34 [==============================] - 12s 352ms/step - loss: 26.4007 - accuracy: 0.6883 - val_loss: 12.0951 - val_accuracy: 0.8149
# Epoch 104/250
# 34/34 [==============================] - 12s 353ms/step - loss: 25.1380 - accuracy: 0.6964 - val_loss: 12.2657 - val_accuracy: 0.8171
# Epoch 105/250
# 34/34 [==============================] - 12s 357ms/step - loss: 24.1696 - accuracy: 0.7038 - val_loss: 12.4671 - val_accuracy: 0.8137
# Epoch 106/250
# 34/34 [==============================] - 12s 356ms/step - loss: 22.2150 - accuracy: 0.7190 - val_loss: 12.2287 - val_accuracy: 0.8104
# Epoch 107/250
# 34/34 [==============================] - 12s 359ms/step - loss: 21.6092 - accuracy: 0.7213 - val_loss: 12.2847 - val_accuracy: 0.8115
# Epoch 108/250
# 34/34 [==============================] - 12s 355ms/step - loss: 20.1879 - accuracy: 0.7374 - val_loss: 12.0256 - val_accuracy: 0.8171
# Epoch 109/250
# 34/34 [==============================] - 12s 355ms/step - loss: 18.0660 - accuracy: 0.7663 - val_loss: 11.7362 - val_accuracy: 0.8226
# Epoch 110/250
# 34/34 [==============================] - 13s 385ms/step - loss: 15.9937 - accuracy: 0.7849 - val_loss: 11.3367 - val_accuracy: 0.8259
# Epoch 111/250
# 34/34 [==============================] - 12s 353ms/step - loss: 14.3813 - accuracy: 0.8004 - val_loss: 11.0394 - val_accuracy: 0.8304
# Epoch 112/250
# 34/34 [==============================] - 12s 356ms/step - loss: 13.3511 - accuracy: 0.8101 - val_loss: 10.9784 - val_accuracy: 0.8304
# Epoch 113/250
# 34/34 [==============================] - 12s 358ms/step - loss: 12.4476 - accuracy: 0.8227 - val_loss: 10.6402 - val_accuracy: 0.8348
# Epoch 114/250
# 34/34 [==============================] - 12s 361ms/step - loss: 12.1106 - accuracy: 0.8241 - val_loss: 10.5626 - val_accuracy: 0.8359
# Epoch 115/250
# 34/34 [==============================] - 12s 356ms/step - loss: 11.5981 - accuracy: 0.8308 - val_loss: 10.3964 - val_accuracy: 0.8370
# Epoch 116/250
# 34/34 [==============================] - 12s 360ms/step - loss: 11.2635 - accuracy: 0.8310 - val_loss: 10.3686 - val_accuracy: 0.8326
# Epoch 117/250
# 34/34 [==============================] - 12s 357ms/step - loss: 11.1328 - accuracy: 0.8303 - val_loss: 10.2267 - val_accuracy: 0.8348
# Epoch 118/250
# 34/34 [==============================] - 12s 354ms/step - loss: 11.2386 - accuracy: 0.8271 - val_loss: 10.1490 - val_accuracy: 0.8315
# Epoch 119/250
# 34/34 [==============================] - 12s 352ms/step - loss: 11.4144 - accuracy: 0.8290 - val_loss: 10.1646 - val_accuracy: 0.8304
# Epoch 120/250
# 34/34 [==============================] - 12s 350ms/step - loss: 11.0339 - accuracy: 0.8264 - val_loss: 10.0099 - val_accuracy: 0.8348
# Epoch 121/250
# 34/34 [==============================] - 12s 351ms/step - loss: 11.1287 - accuracy: 0.8280 - val_loss: 10.0872 - val_accuracy: 0.8271
# Epoch 122/250
# 34/34 [==============================] - 12s 352ms/step - loss: 11.0747 - accuracy: 0.8234 - val_loss: 10.1335 - val_accuracy: 0.8271
# Epoch 123/250
# 34/34 [==============================] - 12s 354ms/step - loss: 11.1287 - accuracy: 0.8239 - val_loss: 9.9682 - val_accuracy: 0.8304
# Epoch 124/250
# 34/34 [==============================] - 12s 349ms/step - loss: 11.3818 - accuracy: 0.8160 - val_loss: 10.0886 - val_accuracy: 0.8248
# Epoch 125/250
# 34/34 [==============================] - 12s 353ms/step - loss: 11.7748 - accuracy: 0.8096 - val_loss: 9.9672 - val_accuracy: 0.8259
# Epoch 126/250
# 34/34 [==============================] - 12s 351ms/step - loss: 11.3406 - accuracy: 0.8163 - val_loss: 9.7810 - val_accuracy: 0.8293
# Epoch 127/250
# 34/34 [==============================] - 12s 349ms/step - loss: 11.3879 - accuracy: 0.8137 - val_loss: 9.8120 - val_accuracy: 0.8271
# Epoch 128/250
# 34/34 [==============================] - 12s 350ms/step - loss: 11.9087 - accuracy: 0.8036 - val_loss: 10.0569 - val_accuracy: 0.8237
# Epoch 129/250
# 34/34 [==============================] - 12s 351ms/step - loss: 12.4976 - accuracy: 0.7937 - val_loss: 10.0197 - val_accuracy: 0.8226
# Epoch 130/250
# 34/34 [==============================] - 12s 351ms/step - loss: 13.2248 - accuracy: 0.7801 - val_loss: 10.1035 - val_accuracy: 0.8204
# Epoch 131/250
# 34/34 [==============================] - 12s 352ms/step - loss: 13.1292 - accuracy: 0.7865 - val_loss: 9.8148 - val_accuracy: 0.8237
# Epoch 132/250
# 34/34 [==============================] - 12s 349ms/step - loss: 13.8210 - accuracy: 0.7817 - val_loss: 9.6621 - val_accuracy: 0.8248
# Epoch 133/250
# 34/34 [==============================] - 12s 353ms/step - loss: 14.0709 - accuracy: 0.7748 - val_loss: 9.7949 - val_accuracy: 0.8226
# Epoch 134/250
# 34/34 [==============================] - 12s 351ms/step - loss: 15.1431 - accuracy: 0.7642 - val_loss: 10.0988 - val_accuracy: 0.8171
# Epoch 135/250
# 34/34 [==============================] - 12s 352ms/step - loss: 16.9922 - accuracy: 0.7367 - val_loss: 10.2389 - val_accuracy: 0.8182
# Epoch 136/250
# 34/34 [==============================] - 13s 381ms/step - loss: 17.6180 - accuracy: 0.7379 - val_loss: 9.9128 - val_accuracy: 0.8215
# Epoch 137/250
# 34/34 [==============================] - 12s 351ms/step - loss: 19.1683 - accuracy: 0.7257 - val_loss: 10.1664 - val_accuracy: 0.8137
# Epoch 138/250
# 34/34 [==============================] - 12s 357ms/step - loss: 20.7270 - accuracy: 0.7056 - val_loss: 10.2943 - val_accuracy: 0.8171
# Epoch 139/250
# 34/34 [==============================] - 12s 354ms/step - loss: 22.7335 - accuracy: 0.7001 - val_loss: 10.4342 - val_accuracy: 0.8182
# Epoch 140/250
# 34/34 [==============================] - 12s 349ms/step - loss: 23.1543 - accuracy: 0.7019 - val_loss: 10.6441 - val_accuracy: 0.8160
# Epoch 141/250
# 34/34 [==============================] - 12s 349ms/step - loss: 24.6144 - accuracy: 0.6842 - val_loss: 11.1104 - val_accuracy: 0.8149
# Epoch 142/250
# 34/34 [==============================] - 12s 350ms/step - loss: 26.3073 - accuracy: 0.6745 - val_loss: 11.4568 - val_accuracy: 0.8149
# Epoch 143/250
# 34/34 [==============================] - 12s 353ms/step - loss: 27.9061 - accuracy: 0.6568 - val_loss: 11.5586 - val_accuracy: 0.8160
# Epoch 144/250
# 34/34 [==============================] - 12s 349ms/step - loss: 28.8096 - accuracy: 0.6586 - val_loss: 11.6135 - val_accuracy: 0.8182
# Epoch 145/250
# 34/34 [==============================] - 12s 353ms/step - loss: 28.7500 - accuracy: 0.6646 - val_loss: 11.6660 - val_accuracy: 0.8215
# Epoch 146/250
# 34/34 [==============================] - 12s 352ms/step - loss: 27.3088 - accuracy: 0.6738 - val_loss: 11.8750 - val_accuracy: 0.8204
# Epoch 147/250
# 34/34 [==============================] - 12s 350ms/step - loss: 25.6444 - accuracy: 0.6787 - val_loss: 12.2085 - val_accuracy: 0.8149
# Epoch 148/250
# 34/34 [==============================] - 12s 354ms/step - loss: 24.1005 - accuracy: 0.6948 - val_loss: 11.9605 - val_accuracy: 0.8215
# Epoch 149/250
# 34/34 [==============================] - 12s 353ms/step - loss: 22.5664 - accuracy: 0.7105 - val_loss: 11.9593 - val_accuracy: 0.8204
# Epoch 150/250
# 34/34 [==============================] - 12s 350ms/step - loss: 20.4196 - accuracy: 0.7273 - val_loss: 12.0972 - val_accuracy: 0.8171
# Epoch 151/250
# 34/34 [==============================] - 12s 350ms/step - loss: 18.0644 - accuracy: 0.7476 - val_loss: 11.7393 - val_accuracy: 0.8237
# Epoch 152/250
# 34/34 [==============================] - 12s 354ms/step - loss: 16.5146 - accuracy: 0.7605 - val_loss: 11.2980 - val_accuracy: 0.8293
# Epoch 153/250
# 34/34 [==============================] - 12s 353ms/step - loss: 14.6581 - accuracy: 0.7858 - val_loss: 10.9636 - val_accuracy: 0.8326
# Epoch 154/250
# 34/34 [==============================] - 12s 353ms/step - loss: 12.3456 - accuracy: 0.8202 - val_loss: 10.6571 - val_accuracy: 0.8348
# Epoch 155/250
# 34/34 [==============================] - 12s 352ms/step - loss: 10.5232 - accuracy: 0.8419 - val_loss: 10.4336 - val_accuracy: 0.8392
# Epoch 156/250
# 34/34 [==============================] - 12s 354ms/step - loss: 9.6681 - accuracy: 0.8511 - val_loss: 10.3067 - val_accuracy: 0.8337
# Epoch 157/250
# 34/34 [==============================] - 12s 354ms/step - loss: 9.2429 - accuracy: 0.8603 - val_loss: 10.1394 - val_accuracy: 0.8359
# Epoch 158/250
# 34/34 [==============================] - 12s 355ms/step - loss: 8.8291 - accuracy: 0.8619 - val_loss: 9.9183 - val_accuracy: 0.8381
# Epoch 159/250
# 34/34 [==============================] - 12s 353ms/step - loss: 8.7172 - accuracy: 0.8638 - val_loss: 9.8492 - val_accuracy: 0.8381
# Epoch 160/250
# 34/34 [==============================] - 12s 350ms/step - loss: 8.4889 - accuracy: 0.8661 - val_loss: 9.7114 - val_accuracy: 0.8359
# Epoch 161/250
# 34/34 [==============================] - 12s 351ms/step - loss: 8.1452 - accuracy: 0.8679 - val_loss: 9.6809 - val_accuracy: 0.8348
# Epoch 162/250
# 34/34 [==============================] - 12s 354ms/step - loss: 8.3048 - accuracy: 0.8649 - val_loss: 9.6378 - val_accuracy: 0.8381
# Epoch 163/250
# 34/34 [==============================] - 12s 357ms/step - loss: 8.2103 - accuracy: 0.8665 - val_loss: 9.4979 - val_accuracy: 0.8370
# Epoch 164/250
# 34/34 [==============================] - 13s 381ms/step - loss: 8.0488 - accuracy: 0.8686 - val_loss: 9.3676 - val_accuracy: 0.8381
# Epoch 165/250
# 34/34 [==============================] - 12s 355ms/step - loss: 8.0569 - accuracy: 0.8670 - val_loss: 9.3338 - val_accuracy: 0.8381
# Epoch 166/250
# 34/34 [==============================] - 12s 354ms/step - loss: 8.0247 - accuracy: 0.8654 - val_loss: 9.2855 - val_accuracy: 0.8381
# Epoch 167/250
# 34/34 [==============================] - 12s 353ms/step - loss: 8.0801 - accuracy: 0.8619 - val_loss: 9.3994 - val_accuracy: 0.8359
# Epoch 168/250
# 34/34 [==============================] - 12s 355ms/step - loss: 8.1570 - accuracy: 0.8564 - val_loss: 9.2118 - val_accuracy: 0.8381
# Epoch 169/250
# 34/34 [==============================] - 12s 361ms/step - loss: 8.3196 - accuracy: 0.8552 - val_loss: 9.1788 - val_accuracy: 0.8370
# Epoch 170/250
# 34/34 [==============================] - 12s 358ms/step - loss: 8.7255 - accuracy: 0.8458 - val_loss: 9.2469 - val_accuracy: 0.8359
# Epoch 171/250
# 34/34 [==============================] - 13s 373ms/step - loss: 8.3797 - accuracy: 0.8465 - val_loss: 9.1503 - val_accuracy: 0.8359
# Epoch 172/250
# 34/34 [==============================] - 12s 367ms/step - loss: 8.2252 - accuracy: 0.8504 - val_loss: 9.0228 - val_accuracy: 0.8404
# Epoch 173/250
# 34/34 [==============================] - 13s 369ms/step - loss: 8.5554 - accuracy: 0.8472 - val_loss: 9.1253 - val_accuracy: 0.8348
# Epoch 174/250
# 34/34 [==============================] - 12s 361ms/step - loss: 8.5067 - accuracy: 0.8442 - val_loss: 9.0205 - val_accuracy: 0.8392
# Epoch 175/250
# 34/34 [==============================] - 12s 357ms/step - loss: 8.9474 - accuracy: 0.8393 - val_loss: 8.9949 - val_accuracy: 0.8392
# Epoch 176/250
# 34/34 [==============================] - 12s 361ms/step - loss: 9.2784 - accuracy: 0.8290 - val_loss: 9.1047 - val_accuracy: 0.8304
# Epoch 177/250
# 34/34 [==============================] - 12s 357ms/step - loss: 9.4526 - accuracy: 0.8246 - val_loss: 9.0783 - val_accuracy: 0.8326
# Epoch 178/250
# 34/34 [==============================] - 12s 359ms/step - loss: 9.9372 - accuracy: 0.8142 - val_loss: 9.1292 - val_accuracy: 0.8315
# Epoch 179/250
# 34/34 [==============================] - 12s 360ms/step - loss: 9.6331 - accuracy: 0.8179 - val_loss: 8.9436 - val_accuracy: 0.8359
# Epoch 180/250
# 34/34 [==============================] - 12s 358ms/step - loss: 10.1278 - accuracy: 0.8137 - val_loss: 8.9513 - val_accuracy: 0.8370
# Epoch 181/250
# 34/34 [==============================] - 12s 359ms/step - loss: 9.7845 - accuracy: 0.8230 - val_loss: 8.8010 - val_accuracy: 0.8370
# Epoch 182/250
# 34/34 [==============================] - 12s 358ms/step - loss: 10.6266 - accuracy: 0.8041 - val_loss: 8.9751 - val_accuracy: 0.8304
# Epoch 183/250
# 34/34 [==============================] - 12s 353ms/step - loss: 11.8544 - accuracy: 0.7842 - val_loss: 9.1888 - val_accuracy: 0.8326
# Epoch 184/250
# 34/34 [==============================] - 12s 358ms/step - loss: 12.1887 - accuracy: 0.7868 - val_loss: 9.0694 - val_accuracy: 0.8282
# Epoch 185/250
# 34/34 [==============================] - 12s 354ms/step - loss: 13.0100 - accuracy: 0.7709 - val_loss: 9.2478 - val_accuracy: 0.8293
# Epoch 186/250
# 34/34 [==============================] - 12s 352ms/step - loss: 13.8416 - accuracy: 0.7656 - val_loss: 9.3219 - val_accuracy: 0.8271
# Epoch 187/250
# 34/34 [==============================] - 12s 358ms/step - loss: 15.2716 - accuracy: 0.7480 - val_loss: 9.4551 - val_accuracy: 0.8271
# Epoch 188/250
# 34/34 [==============================] - 12s 360ms/step - loss: 16.0790 - accuracy: 0.7441 - val_loss: 9.4612 - val_accuracy: 0.8271
# Epoch 189/250
# 34/34 [==============================] - 12s 354ms/step - loss: 17.4867 - accuracy: 0.7282 - val_loss: 9.6985 - val_accuracy: 0.8226
# Epoch 190/250
# 34/34 [==============================] - 13s 391ms/step - loss: 18.9684 - accuracy: 0.7225 - val_loss: 9.7604 - val_accuracy: 0.8182
# Epoch 191/250
# 34/34 [==============================] - 12s 357ms/step - loss: 21.7705 - accuracy: 0.6946 - val_loss: 10.1647 - val_accuracy: 0.8160
# Epoch 192/250
# 34/34 [==============================] - 12s 355ms/step - loss: 25.4095 - accuracy: 0.6763 - val_loss: 10.4702 - val_accuracy: 0.8160
# Epoch 193/250
# 34/34 [==============================] - 12s 359ms/step - loss: 25.9099 - accuracy: 0.6782 - val_loss: 10.5326 - val_accuracy: 0.8215
# Epoch 194/250
# 34/34 [==============================] - 12s 353ms/step - loss: 25.0008 - accuracy: 0.6934 - val_loss: 10.5689 - val_accuracy: 0.8237
# Epoch 195/250
# 34/34 [==============================] - 12s 354ms/step - loss: 24.7577 - accuracy: 0.6858 - val_loss: 11.0261 - val_accuracy: 0.8160
# Epoch 196/250
# 34/34 [==============================] - 12s 357ms/step - loss: 25.0571 - accuracy: 0.6798 - val_loss: 11.5016 - val_accuracy: 0.8171
# Epoch 197/250
# 34/34 [==============================] - 12s 355ms/step - loss: 25.7266 - accuracy: 0.6720 - val_loss: 11.7707 - val_accuracy: 0.8193
# Epoch 198/250
# 34/34 [==============================] - 12s 356ms/step - loss: 25.0061 - accuracy: 0.6803 - val_loss: 11.8019 - val_accuracy: 0.8204
# Epoch 199/250
# 34/34 [==============================] - 12s 356ms/step - loss: 22.6327 - accuracy: 0.6969 - val_loss: 11.8745 - val_accuracy: 0.8182
# Epoch 200/250
# 34/34 [==============================] - 12s 353ms/step - loss: 19.7666 - accuracy: 0.7236 - val_loss: 11.5298 - val_accuracy: 0.8226
# Epoch 201/250
# 34/34 [==============================] - 12s 359ms/step - loss: 17.3714 - accuracy: 0.7425 - val_loss: 11.5857 - val_accuracy: 0.8193
# Epoch 202/250
# 34/34 [==============================] - 12s 361ms/step - loss: 14.1288 - accuracy: 0.7741 - val_loss: 11.2603 - val_accuracy: 0.8237
# Epoch 203/250
# 34/34 [==============================] - 12s 361ms/step - loss: 12.0293 - accuracy: 0.8068 - val_loss: 10.7070 - val_accuracy: 0.8282
# Epoch 204/250
# 34/34 [==============================] - 12s 362ms/step - loss: 10.6234 - accuracy: 0.8213 - val_loss: 10.4722 - val_accuracy: 0.8326
# Epoch 205/250
# 34/34 [==============================] - 12s 363ms/step - loss: 9.1473 - accuracy: 0.8467 - val_loss: 10.1025 - val_accuracy: 0.8359
# Epoch 206/250
# 34/34 [==============================] - 12s 360ms/step - loss: 8.0166 - accuracy: 0.8672 - val_loss: 9.8862 - val_accuracy: 0.8381
# Epoch 207/250
# 34/34 [==============================] - 12s 366ms/step - loss: 7.4610 - accuracy: 0.8744 - val_loss: 9.6853 - val_accuracy: 0.8404
# Epoch 208/250
# 34/34 [==============================] - 12s 358ms/step - loss: 7.2756 - accuracy: 0.8794 - val_loss: 9.6473 - val_accuracy: 0.8370
# Epoch 209/250
# 34/34 [==============================] - 12s 361ms/step - loss: 6.8127 - accuracy: 0.8866 - val_loss: 9.4541 - val_accuracy: 0.8404
# Epoch 210/250
# 34/34 [==============================] - 12s 359ms/step - loss: 6.4632 - accuracy: 0.8935 - val_loss: 9.3632 - val_accuracy: 0.8392
# Epoch 211/250
# 34/34 [==============================] - 12s 357ms/step - loss: 6.2398 - accuracy: 0.8928 - val_loss: 9.3622 - val_accuracy: 0.8381
# Epoch 212/250
# 34/34 [==============================] - 12s 362ms/step - loss: 6.2463 - accuracy: 0.8917 - val_loss: 9.2591 - val_accuracy: 0.8415
# Epoch 213/250
# 34/34 [==============================] - 12s 353ms/step - loss: 6.1967 - accuracy: 0.8889 - val_loss: 9.2290 - val_accuracy: 0.8404
# Epoch 214/250
# 34/34 [==============================] - 12s 361ms/step - loss: 6.1604 - accuracy: 0.8880 - val_loss: 9.1991 - val_accuracy: 0.8404
# Epoch 215/250
# 34/34 [==============================] - 12s 358ms/step - loss: 6.1333 - accuracy: 0.8942 - val_loss: 9.0028 - val_accuracy: 0.8448
# Epoch 216/250
# 34/34 [==============================] - 13s 394ms/step - loss: 6.1683 - accuracy: 0.8880 - val_loss: 8.9660 - val_accuracy: 0.8459
# Epoch 217/250
# 34/34 [==============================] - 12s 359ms/step - loss: 6.3404 - accuracy: 0.8820 - val_loss: 8.9983 - val_accuracy: 0.8404
# Epoch 218/250
# 34/34 [==============================] - 12s 355ms/step - loss: 6.6101 - accuracy: 0.8751 - val_loss: 9.0230 - val_accuracy: 0.8392
# Epoch 219/250
# 34/34 [==============================] - 12s 355ms/step - loss: 6.2909 - accuracy: 0.8831 - val_loss: 8.8351 - val_accuracy: 0.8437
# Epoch 220/250
# 34/34 [==============================] - 12s 356ms/step - loss: 6.2795 - accuracy: 0.8831 - val_loss: 8.9573 - val_accuracy: 0.8415
# Epoch 221/250
# 34/34 [==============================] - 12s 360ms/step - loss: 5.9863 - accuracy: 0.8864 - val_loss: 8.8336 - val_accuracy: 0.8404
# Epoch 222/250
# 34/34 [==============================] - 12s 362ms/step - loss: 5.7772 - accuracy: 0.8935 - val_loss: 8.7444 - val_accuracy: 0.8426
# Epoch 223/250
# 34/34 [==============================] - 12s 359ms/step - loss: 5.8070 - accuracy: 0.8898 - val_loss: 8.6871 - val_accuracy: 0.8437
# Epoch 224/250
# 34/34 [==============================] - 12s 358ms/step - loss: 5.8731 - accuracy: 0.8868 - val_loss: 8.6946 - val_accuracy: 0.8404
# Epoch 225/250
# 34/34 [==============================] - 12s 361ms/step - loss: 5.7135 - accuracy: 0.8891 - val_loss: 8.6107 - val_accuracy: 0.8415
# Epoch 226/250
# 34/34 [==============================] - 12s 356ms/step - loss: 5.8305 - accuracy: 0.8850 - val_loss: 8.5767 - val_accuracy: 0.8404
# Epoch 227/250
# 34/34 [==============================] - 12s 359ms/step - loss: 5.8848 - accuracy: 0.8824 - val_loss: 8.5630 - val_accuracy: 0.8415
# Epoch 228/250
# 34/34 [==============================] - 12s 356ms/step - loss: 5.8191 - accuracy: 0.8813 - val_loss: 8.5494 - val_accuracy: 0.8392
# Epoch 229/250
# 34/34 [==============================] - 12s 353ms/step - loss: 5.9785 - accuracy: 0.8815 - val_loss: 8.4755 - val_accuracy: 0.8392
# Epoch 230/250
# 34/34 [==============================] - 12s 360ms/step - loss: 6.2859 - accuracy: 0.8672 - val_loss: 8.5121 - val_accuracy: 0.8337
# Epoch 231/250
# 34/34 [==============================] - 12s 358ms/step - loss: 6.6417 - accuracy: 0.8598 - val_loss: 8.4830 - val_accuracy: 0.8359
# Epoch 232/250
# 34/34 [==============================] - 12s 359ms/step - loss: 6.7341 - accuracy: 0.8545 - val_loss: 8.3926 - val_accuracy: 0.8404
# Epoch 233/250
# 34/34 [==============================] - 12s 360ms/step - loss: 7.1835 - accuracy: 0.8456 - val_loss: 8.5106 - val_accuracy: 0.8359
# Epoch 234/250
# 34/34 [==============================] - 12s 357ms/step - loss: 7.4382 - accuracy: 0.8444 - val_loss: 8.5519 - val_accuracy: 0.8304
# Epoch 235/250
# 34/34 [==============================] - 12s 359ms/step - loss: 7.3309 - accuracy: 0.8474 - val_loss: 8.4174 - val_accuracy: 0.8359
# Epoch 236/250
# 34/34 [==============================] - 12s 363ms/step - loss: 7.5178 - accuracy: 0.8460 - val_loss: 8.3309 - val_accuracy: 0.8370
# Epoch 237/250
# 34/34 [==============================] - 12s 359ms/step - loss: 7.8454 - accuracy: 0.8379 - val_loss: 8.3963 - val_accuracy: 0.8337
# Epoch 238/250
# 34/34 [==============================] - 12s 354ms/step - loss: 7.7163 - accuracy: 0.8405 - val_loss: 8.2465 - val_accuracy: 0.8392
# Epoch 239/250
# 34/34 [==============================] - 12s 356ms/step - loss: 8.4097 - accuracy: 0.8239 - val_loss: 8.4970 - val_accuracy: 0.8326
# Epoch 240/250
# 34/34 [==============================] - 12s 353ms/step - loss: 8.8828 - accuracy: 0.8107 - val_loss: 8.5102 - val_accuracy: 0.8304
# Epoch 241/250
# 34/34 [==============================] - 12s 358ms/step - loss: 9.3538 - accuracy: 0.8158 - val_loss: 8.5885 - val_accuracy: 0.8282
# Epoch 242/250
# 34/34 [==============================] - 12s 355ms/step - loss: 10.1967 - accuracy: 0.8027 - val_loss: 8.6002 - val_accuracy: 0.8282
# Epoch 243/250
# 34/34 [==============================] - 13s 389ms/step - loss: 10.6648 - accuracy: 0.7923 - val_loss: 8.7090 - val_accuracy: 0.8271
# Epoch 244/250
# 34/34 [==============================] - 12s 355ms/step - loss: 11.8522 - accuracy: 0.7748 - val_loss: 8.7965 - val_accuracy: 0.8271
# Epoch 245/250
# 34/34 [==============================] - 12s 356ms/step - loss: 13.0761 - accuracy: 0.7665 - val_loss: 8.9599 - val_accuracy: 0.8259
# Epoch 246/250
# 34/34 [==============================] - 12s 357ms/step - loss: 13.7964 - accuracy: 0.7573 - val_loss: 8.9689 - val_accuracy: 0.8259
# Epoch 247/250
# 34/34 [==============================] - 12s 356ms/step - loss: 15.3168 - accuracy: 0.7501 - val_loss: 9.1040 - val_accuracy: 0.8237
# Epoch 248/250
# 34/34 [==============================] - 12s 359ms/step - loss: 17.8970 - accuracy: 0.7162 - val_loss: 9.4770 - val_accuracy: 0.8182
# Epoch 249/250
# 34/34 [==============================] - 12s 360ms/step - loss: 20.4149 - accuracy: 0.7065 - val_loss: 9.6089 - val_accuracy: 0.8171
# Epoch 250/250
# 34/34 [==============================] - 12s 358ms/step - loss: 22.5985 - accuracy: 0.6953 - val_loss: 9.7955 - val_accuracy: 0.8160
# run epochs:  250
# 6/6 [==============================] - 149s 25s/step - loss: 9.5948 - accuracy: 0.8093
# classification report: resnet50_NOdataAug_dropoutFirst007-synth_data_for_bath_kitchen_trainVal
#                precision    recall  f1-score   support
#
#      Bedroom       0.89      0.93      0.91       211
#     Bathroom       0.84      0.94      0.89        82
#      Dinning       0.69      0.85      0.76       164
#   Livingroom       0.80      0.81      0.81       223
#      Kitchen       0.88      0.64      0.74       222
#
#     accuracy                           0.82       902
#    macro avg       0.82      0.83      0.82       902
# weighted avg       0.82      0.82      0.81       902
# 6/6 [==============================] - 2s 318ms/step - loss: 9.5948 - accuracy: 0.8093
# classification report: resnet50_NOdataAug_dropoutFirst007-synth_data_for_bath_kitchen_trainTest
#                precision    recall  f1-score   support
#
#      Bedroom       0.83      0.89      0.86       139
#     Bathroom       0.84      0.92      0.88       137
#      Dinning       0.70      0.85      0.77       124
#   Livingroom       0.82      0.77      0.79       160
#      Kitchen       0.86      0.68      0.76       190
#
#     accuracy                           0.81       750
#    macro avg       0.81      0.82      0.81       750
# weighted avg       0.82      0.81      0.81       750
